# %% [markdown]
# <a href="https://colab.research.google.com/github/AEW2015/altera_examples/blob/main/py_AI/colab/yolov8_fpga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # YOLOv8 example for Altera FPGA AI Suite

# %%
import torch

# Check PyTorch version
pt_version = torch.__version__
print(f"[INFO] Current PyTorch version: {pt_version} (should be 2.x+)")

# Install PyTorch 2.0 if necessary
if pt_version.split(".")[0] == "1": # Check if PyTorch version begins with 1
    # !pip3 install -U torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
    print("[INFO] PyTorch 2.x installed, if you're on Google Colab, you may need to restart your runtime.\
          Though as of April 2023, Google Colab comes with PyTorch 2.0 pre-installed.")
    import torch
    pt_version = torch.__version__
    print(f"[INFO] Current PyTorch version: {pt_version} (should be 2.x+)")
else:
    print("[INFO] PyTorch 2.x installed, you'll be able to use the new features.")
# Out:
# [INFO] Current PyTorch version: 2.5.1+cu121 (should be 2.x+)
# [INFO] PyTorch 2.x installed, you'll be able to use the new features.

# %%
# Make sure we're using a NVIDIA GPU
if torch.cuda.is_available():
  gpu_info = !nvidia-smi
  gpu_info = '\n'.join(gpu_info)
  if gpu_info.find("failed") >= 0:
    print("Not connected to a GPU, to leverage the best of PyTorch 2.0, you should connect to a GPU.")

  # Get GPU name
  gpu_name = !nvidia-smi --query-gpu=gpu_name --format=csv
  gpu_name = gpu_name[1]
  GPU_NAME = gpu_name.replace(" ", "_") # remove underscores for easier saving
  print(f'GPU name: {GPU_NAME}')

  # Get GPU capability score
  GPU_SCORE = torch.cuda.get_device_capability()
  print(f"GPU capability score: {GPU_SCORE}")
  if GPU_SCORE >= (8, 0):
    print(f"GPU score higher than or equal to (8, 0), PyTorch 2.x speedup features available.")
  else:
    print(f"GPU score lower than (8, 0), PyTorch 2.x speedup features will be limited (PyTorch 2.x speedups happen most on newer GPUs).")

  # Print GPU info
  print(f"GPU information:\n{gpu_info}")

else:
  print("PyTorch couldn't find a GPU, to leverage the best of PyTorch 2.0, you should connect to a GPU.")
# Out:
# GPU name: Tesla_T4
# GPU capability score: (7, 5)
# GPU score lower than (8, 0), PyTorch 2.x speedup features will be limited (PyTorch 2.x speedups happen most on newer GPUs).
# GPU information:
# Wed Nov 20 03:23:57 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              11W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# ## Download YOLO model

# %%
pip install ultralytics -qq

# %%
from ultralytics import YOLO

# Load the YOLO11 model
model = YOLO("yolov8n-cls.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n-cls.pt to 'yolov8n-cls.pt'...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 253MB/s]

# %%
results = model("https://ultralytics.com/images/bus.jpg")  # predict on an image
# Out:
# Downloading https://ultralytics.com/images/bus.jpg to 'bus.jpg'...
# 100%|██████████| 134k/134k [00:00<00:00, 37.1MB/s]
# image 1/1 /content/bus.jpg: 224x224 minibus 0.50, police_van 0.29, trolleybus 0.05, golfcart 0.02, jinrikisha 0.02, 3.4ms
# Speed: 35.2ms preprocess, 3.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %% [markdown]
# Export as ONNX

# %%
# Export the model to ONNX format
model.export(format="onnx",batch=1,opset=11)
# Out:
# Ultralytics 8.3.34 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.00GHz)
# YOLOv8n-cls summary (fused): 73 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# PyTorch: starting from 'yolov8n-cls.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 1000) (5.3 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Collecting onnx>=1.12.0
#   Downloading onnx-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting onnxslim
#   Downloading onnxslim-0.1.39-py3-none-any.whl.metadata (2.9 kB)
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.20.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.12.0) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.12.0) (4.25.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxslim) (1.13.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxslim) (24.2)
# Collecting coloredlogs (from onnxruntime-gpu)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime-gpu) (24.3.25)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxslim) (1.3.0)
# Downloading onnx-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 185.7 MB/s eta 0:00:00
# Downloading onnxslim-0.1.39-py3-none-any.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.8/141.8 kB 298.3 MB/s eta 0:00:00
# Downloading onnxruntime_gpu-1.20.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (291.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.5/291.5 MB 47.9 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 212.1 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 316.5 MB/s eta 0:00:00
# Installing collected packages: onnx, humanfriendly, onnxslim, coloredlogs, onnxruntime-gpu
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnx-1.17.0 onnxruntime-gpu-1.20.0 onnxslim-0.1.39
#
# requirements: AutoUpdate success ✅ 19.7s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim', 'onnxruntime-gpu']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.17.0 opset 11...
# ONNX: slimming with onnxslim 0.1.39...
# ONNX: export success ✅ 20.2s, saved as 'yolov8n-cls.onnx' (10.4 MB)
#
# Export complete (22.2s)
# Results saved to /content
# Predict:         yolo predict task=classify model=yolov8n-cls.onnx imgsz=224
# Validate:        yolo val task=classify model=yolov8n-cls.onnx imgsz=224 data=../datasets/imagenet
# Visualize:       https://netron.app
# 'yolov8n-cls.onnx'

# %% [markdown]
# OpenVINO command to compile
#
# `mo --input_model yolov8n-cls.onnx  --output_dir ./yolov8  --reverse_input_channels`

# %% [markdown]
# Checkout the DOT Kernel

# %% [markdown]
# Build the benchmark image
#
# ```
# dla_compiler --march $COREDLA_ROOT/example_architectures/AGX7_Performance.arch --network-file ./yolov8n-cls.xml --foutput-format=open_vino_hetero --o ./yolov8_bench.bin --batch-size=1 --fanalyze-performance
# ```

# %% [markdown]
# Run on the FPGA:
#
# ```
# uio-devices restart
# export compiled_model=~/resnet-50-tf/yolov8_bench.bin
# export imgdir=~/resnet-50-tf/sample_images
# export archfile=~/resnet-50-tf/AGX7_Performance.arch
# cd ~/app
# export COREDLA_ROOT=/home/root/app
# ./dla_benchmark -b=1 -cm $compiled_model -d=HETERO:FPGA,CPU -i $imgdir -niter=5 -plugins_xml_file ./plugins.xml -arch_file $archfile -api=async -perf_est  -nireq=4 -bgr
# ```

# %% [markdown]
# ## Performace Testing

# %%
# Example: Dummy dataset with random data
from PIL import Image
import numpy as np

# Generate random images to simulate a dataset
def generate_dummy_images(num_images, size=(224, 224)):
    images = []
    for _ in range(num_images):
        array = np.random.randint(0, 255, size + (3,), dtype=np.uint8)
        images.append(Image.fromarray(array))
    return images

images = generate_dummy_images(2000)

# %%
from time import *
# Ensure GPU is available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

# Convert images to tensors and move to the appropriate device
processed_images = [torch.tensor(np.array(img).transpose(2, 0, 1), dtype=torch.float32) / 255.0 for img in images]
processed_images = [img.unsqueeze(0) for img in processed_images]  # Add batch dimension

# Batch the images
batch_size = 2000  # Adjust batch size for performance vs memory tradeoff
batches = [torch.cat(processed_images[i:i + batch_size], dim=0).to(device) for i in range(0, len(processed_images), batch_size)]

# Run inference and measure speed
times = []
for batch in batches:
    start_time = time()
    results = model.predict(batch)  # Let YOLO handle preprocessing and inference
    elapsed_time = time() - start_time
    times.append(elapsed_time)
# Out:
# Using device: cuda
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 224x224 paper_towel 0.08, tennis_ball 0.04, velvet 0.04, vulture 0.03, bubble 0.03, 0.2ms
# 1: 224x224 paper_towel 0.09, velvet 0.07, dishrag 0.06, tennis_ball 0.04, tick 0.03, 0.2ms
# 2: 224x224 velvet 0.07, paper_towel 0.06, tennis_ball 0.05, dishrag 0.05, vulture 0.03, 0.2ms
# 3: 224x224 tennis_ball 0.06, paper_towel 0.05, velvet 0.04, vulture 0.04, tick 0.03, 0.2ms
# 4: 224x224 paper_towel 0.08, dishrag 0.06, velvet 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 5: 224x224 paper_towel 0.08, dishrag 0.06, tennis_ball 0.04, velvet 0.04, tick 0.03, 0.2ms
# 6: 224x224 paper_towel 0.06, dishrag 0.06, velvet 0.05, tennis_ball 0.04, tick 0.03, 0.2ms
# 7: 224x224 paper_towel 0.07, dishrag 0.06, tennis_ball 0.04, velvet 0.04, vulture 0.03, 0.2ms
# 8: 224x224 paper_towel 0.07, velvet 0.06, dishrag 0.05, vulture 0.03, tennis_ball 0.03, 0.2ms
# 9: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.05, dishrag 0.05, tick 0.03, 0.2ms
# 10: 224x224 paper_towel 0.07, velvet 0.07, dishrag 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 11: 224x224 dishrag 0.14, paper_towel 0.07, velvet 0.05, cardigan 0.04, tennis_ball 0.04, 0.2ms
# 12: 224x224 tennis_ball 0.06, paper_towel 0.05, velvet 0.04, dishrag 0.03, tick 0.03, 0.2ms
# 13: 224x224 paper_towel 0.09, tennis_ball 0.05, velvet 0.05, dishrag 0.04, bubble 0.03, 0.2ms
# 14: 224x224 velvet 0.07, paper_towel 0.06, tennis_ball 0.05, dishrag 0.05, cardigan 0.02, 0.2ms
# 15: 224x224 velvet 0.05, paper_towel 0.05, tennis_ball 0.04, dishrag 0.04, tick 0.04, 0.2ms
# 16: 224x224 paper_towel 0.08, velvet 0.05, tennis_ball 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 17: 224x224 vulture 0.05, velvet 0.05, paper_towel 0.04, tennis_ball 0.04, tick 0.04, 0.2ms
# 18: 224x224 dishrag 0.08, velvet 0.08, paper_towel 0.06, tennis_ball 0.05, tick 0.04, 0.2ms
# 19: 224x224 paper_towel 0.06, tennis_ball 0.06, dishrag 0.04, velvet 0.04, vulture 0.03, 0.2ms
# 20: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.05, dishrag 0.05, vulture 0.03, 0.2ms
# 21: 224x224 dishrag 0.06, paper_towel 0.06, tennis_ball 0.05, velvet 0.04, vulture 0.03, 0.2ms
# 22: 224x224 paper_towel 0.07, velvet 0.06, vulture 0.04, tennis_ball 0.04, tick 0.04, 0.2ms
# 23: 224x224 paper_towel 0.08, velvet 0.06, tennis_ball 0.05, dishrag 0.05, wool 0.03, 0.2ms
# 24: 224x224 dishrag 0.10, paper_towel 0.06, velvet 0.05, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 25: 224x224 dishrag 0.07, paper_towel 0.06, velvet 0.04, tick 0.04, tennis_ball 0.03, 0.2ms
# 26: 224x224 velvet 0.06, paper_towel 0.06, tennis_ball 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 27: 224x224 tennis_ball 0.06, paper_towel 0.06, velvet 0.04, vulture 0.04, dishrag 0.03, 0.2ms
# 28: 224x224 paper_towel 0.10, tennis_ball 0.06, velvet 0.05, tick 0.04, dishrag 0.03, 0.2ms
# 29: 224x224 paper_towel 0.08, dishrag 0.06, tennis_ball 0.04, velvet 0.04, tick 0.03, 0.2ms
# 30: 224x224 dishrag 0.10, paper_towel 0.05, velvet 0.05, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 31: 224x224 paper_towel 0.06, tennis_ball 0.05, velvet 0.05, vulture 0.04, dishrag 0.04, 0.2ms
# 32: 224x224 dishrag 0.13, paper_towel 0.10, tennis_ball 0.05, velvet 0.05, cardigan 0.03, 0.2ms
# 33: 224x224 paper_towel 0.08, dishrag 0.06, velvet 0.06, tennis_ball 0.05, tick 0.03, 0.2ms
# 34: 224x224 paper_towel 0.07, tennis_ball 0.06, tick 0.05, vulture 0.04, velvet 0.04, 0.2ms
# 35: 224x224 paper_towel 0.07, velvet 0.05, tick 0.04, tennis_ball 0.04, screw 0.03, 0.2ms
# 36: 224x224 velvet 0.05, paper_towel 0.05, tennis_ball 0.04, dishrag 0.04, tick 0.04, 0.2ms
# 37: 224x224 dishrag 0.07, tennis_ball 0.07, paper_towel 0.06, velvet 0.06, cardigan 0.03, 0.2ms
# 38: 224x224 paper_towel 0.10, tennis_ball 0.06, velvet 0.04, dishrag 0.04, cardigan 0.02, 0.2ms
# 39: 224x224 dishrag 0.08, paper_towel 0.06, velvet 0.05, tennis_ball 0.04, wool 0.03, 0.2ms
# 40: 224x224 dishrag 0.09, paper_towel 0.08, velvet 0.05, stole 0.04, tennis_ball 0.04, 0.2ms
# 41: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.05, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 42: 224x224 paper_towel 0.07, tennis_ball 0.04, velvet 0.04, vulture 0.03, tick 0.03, 0.2ms
# 43: 224x224 dishrag 0.12, paper_towel 0.07, velvet 0.06, vulture 0.03, tick 0.03, 0.2ms
# 44: 224x224 paper_towel 0.07, velvet 0.05, dishrag 0.05, tennis_ball 0.05, tick 0.04, 0.2ms
# 45: 224x224 paper_towel 0.08, velvet 0.05, tennis_ball 0.05, dishrag 0.04, screw 0.03, 0.2ms
# 46: 224x224 velvet 0.09, dishrag 0.08, paper_towel 0.05, tennis_ball 0.05, wool 0.03, 0.2ms
# 47: 224x224 paper_towel 0.05, velvet 0.05, tennis_ball 0.05, tick 0.04, vulture 0.04, 0.2ms
# 48: 224x224 dishrag 0.08, paper_towel 0.06, velvet 0.05, tennis_ball 0.05, cardigan 0.04, 0.2ms
# 49: 224x224 velvet 0.06, dishrag 0.06, paper_towel 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 50: 224x224 paper_towel 0.07, velvet 0.06, dishrag 0.05, vulture 0.04, tick 0.04, 0.2ms
# 51: 224x224 paper_towel 0.05, velvet 0.05, vulture 0.05, dishrag 0.04, tennis_ball 0.04, 0.2ms
# 52: 224x224 dishrag 0.09, paper_towel 0.06, velvet 0.04, cardigan 0.04, tennis_ball 0.04, 0.2ms
# 53: 224x224 paper_towel 0.08, dishrag 0.06, velvet 0.04, tennis_ball 0.03, tick 0.03, 0.2ms
# 54: 224x224 dishrag 0.05, tennis_ball 0.04, velvet 0.04, paper_towel 0.04, wool 0.03, 0.2ms
# 55: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.05, tennis_ball 0.04, vulture 0.04, 0.2ms
# 56: 224x224 velvet 0.06, dishrag 0.06, paper_towel 0.06, tennis_ball 0.04, vulture 0.03, 0.2ms
# 57: 224x224 paper_towel 0.06, velvet 0.05, dishrag 0.05, tennis_ball 0.04, vulture 0.04, 0.2ms
# 58: 224x224 paper_towel 0.08, tennis_ball 0.05, dishrag 0.05, velvet 0.04, tick 0.03, 0.2ms
# 59: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.05, tennis_ball 0.04, screw 0.03, 0.2ms
# 60: 224x224 paper_towel 0.06, tennis_ball 0.05, velvet 0.04, dishrag 0.04, vulture 0.03, 0.2ms
# 61: 224x224 dishrag 0.09, paper_towel 0.07, velvet 0.07, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 62: 224x224 velvet 0.07, dishrag 0.05, paper_towel 0.05, tennis_ball 0.04, vulture 0.03, 0.2ms
# 63: 224x224 paper_towel 0.07, velvet 0.06, dishrag 0.06, tennis_ball 0.05, vulture 0.03, 0.2ms
# 64: 224x224 velvet 0.06, paper_towel 0.06, dishrag 0.05, tennis_ball 0.04, bubble 0.03, 0.2ms
# 65: 224x224 dishrag 0.14, paper_towel 0.07, velvet 0.05, cardigan 0.04, tennis_ball 0.04, 0.2ms
# 66: 224x224 dishrag 0.14, paper_towel 0.07, cardigan 0.05, tennis_ball 0.04, velvet 0.04, 0.2ms
# 67: 224x224 paper_towel 0.08, dishrag 0.07, tennis_ball 0.05, velvet 0.04, stole 0.03, 0.2ms
# 68: 224x224 paper_towel 0.09, tennis_ball 0.06, velvet 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 69: 224x224 dishrag 0.06, paper_towel 0.06, velvet 0.05, tennis_ball 0.04, stole 0.03, 0.2ms
# 70: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.05, dishrag 0.05, cardigan 0.03, 0.2ms
# 71: 224x224 tennis_ball 0.06, velvet 0.05, paper_towel 0.05, dishrag 0.04, vulture 0.04, 0.2ms
# 72: 224x224 tennis_ball 0.07, dishrag 0.06, velvet 0.06, paper_towel 0.05, vulture 0.03, 0.2ms
# 73: 224x224 paper_towel 0.07, velvet 0.06, dishrag 0.05, tick 0.04, vulture 0.04, 0.2ms
# 74: 224x224 velvet 0.07, paper_towel 0.06, dishrag 0.04, tennis_ball 0.04, tick 0.03, 0.2ms
# 75: 224x224 velvet 0.08, dishrag 0.06, paper_towel 0.04, vulture 0.04, tick 0.03, 0.2ms
# 76: 224x224 paper_towel 0.08, tennis_ball 0.05, velvet 0.05, dishrag 0.04, cardigan 0.03, 0.2ms
# 77: 224x224 velvet 0.09, dishrag 0.07, paper_towel 0.06, tennis_ball 0.04, vulture 0.03, 0.2ms
# 78: 224x224 paper_towel 0.08, dishrag 0.05, velvet 0.05, tick 0.05, tennis_ball 0.03, 0.2ms
# 79: 224x224 paper_towel 0.06, velvet 0.05, dishrag 0.05, vulture 0.05, tick 0.04, 0.2ms
# 80: 224x224 paper_towel 0.07, velvet 0.07, dishrag 0.07, tennis_ball 0.04, tick 0.03, 0.2ms
# 81: 224x224 dishrag 0.05, paper_towel 0.05, vulture 0.04, velvet 0.04, tennis_ball 0.04, 0.2ms
# 82: 224x224 dishrag 0.10, velvet 0.08, paper_towel 0.04, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 83: 224x224 paper_towel 0.09, velvet 0.06, tennis_ball 0.05, dishrag 0.04, vulture 0.03, 0.2ms
# 84: 224x224 velvet 0.05, paper_towel 0.05, dishrag 0.04, vulture 0.04, tennis_ball 0.04, 0.2ms
# 85: 224x224 paper_towel 0.07, dishrag 0.06, tennis_ball 0.06, velvet 0.05, screw 0.03, 0.2ms
# 86: 224x224 paper_towel 0.06, velvet 0.06, tick 0.05, tennis_ball 0.04, vulture 0.04, 0.2ms
# 87: 224x224 tennis_ball 0.06, velvet 0.05, paper_towel 0.05, dishrag 0.04, vulture 0.04, 0.2ms
# 88: 224x224 velvet 0.10, paper_towel 0.06, dishrag 0.06, vulture 0.04, tick 0.04, 0.2ms
# 89: 224x224 paper_towel 0.08, velvet 0.05, tennis_ball 0.04, dishrag 0.04, vulture 0.03, 0.2ms
# 90: 224x224 paper_towel 0.07, velvet 0.05, dishrag 0.04, tick 0.04, vulture 0.03, 0.2ms
# 91: 224x224 velvet 0.06, paper_towel 0.05, tennis_ball 0.05, dishrag 0.04, bubble 0.03, 0.2ms
# 92: 224x224 paper_towel 0.10, dishrag 0.06, velvet 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 93: 224x224 paper_towel 0.08, dishrag 0.07, velvet 0.04, tennis_ball 0.04, screw 0.03, 0.2ms
# 94: 224x224 tennis_ball 0.07, paper_towel 0.06, velvet 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 95: 224x224 paper_towel 0.07, tennis_ball 0.06, dishrag 0.05, velvet 0.04, tick 0.03, 0.2ms
# 96: 224x224 dishrag 0.13, paper_towel 0.08, velvet 0.05, cardigan 0.04, tennis_ball 0.03, 0.2ms
# 97: 224x224 paper_towel 0.06, tennis_ball 0.06, velvet 0.06, dishrag 0.04, tick 0.03, 0.2ms
# 98: 224x224 tennis_ball 0.06, paper_towel 0.06, velvet 0.05, dishrag 0.04, cardigan 0.03, 0.2ms
# 99: 224x224 paper_towel 0.06, tennis_ball 0.06, velvet 0.05, tick 0.03, vulture 0.03, 0.2ms
# 100: 224x224 paper_towel 0.09, velvet 0.07, tennis_ball 0.06, tick 0.04, dishrag 0.04, 0.2ms
# 101: 224x224 velvet 0.07, paper_towel 0.06, tennis_ball 0.05, vulture 0.04, dishrag 0.04, 0.2ms
# 102: 224x224 paper_towel 0.06, velvet 0.04, tennis_ball 0.04, vulture 0.04, tick 0.04, 0.2ms
# 103: 224x224 paper_towel 0.08, dishrag 0.05, velvet 0.04, tennis_ball 0.04, tick 0.03, 0.2ms
# 104: 224x224 paper_towel 0.09, dishrag 0.08, velvet 0.06, cardigan 0.04, tennis_ball 0.03, 0.2ms
# 105: 224x224 paper_towel 0.08, tick 0.06, velvet 0.05, tennis_ball 0.04, vulture 0.03, 0.2ms
# 106: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.05, vulture 0.04, tick 0.03, 0.2ms
# 107: 224x224 paper_towel 0.07, velvet 0.06, tennis_ball 0.05, vulture 0.04, dishrag 0.04, 0.2ms
# 108: 224x224 velvet 0.08, dishrag 0.06, tennis_ball 0.05, paper_towel 0.05, vulture 0.04, 0.2ms
# 109: 224x224 dishrag 0.10, paper_towel 0.09, velvet 0.06, stole 0.05, cardigan 0.04, 0.2ms
# 110: 224x224 velvet 0.06, dishrag 0.06, paper_towel 0.05, vulture 0.05, tick 0.04, 0.2ms
# 111: 224x224 velvet 0.07, paper_towel 0.06, vulture 0.05, tennis_ball 0.04, dishrag 0.04, 0.2ms
# 112: 224x224 paper_towel 0.06, tennis_ball 0.06, velvet 0.05, dishrag 0.05, vulture 0.03, 0.2ms
# 113: 224x224 dishrag 0.09, paper_towel 0.09, velvet 0.05, tennis_ball 0.05, vulture 0.03, 0.2ms
# 114: 224x224 paper_towel 0.07, tennis_ball 0.05, dishrag 0.05, velvet 0.04, vulture 0.04, 0.2ms
# 115: 224x224 paper_towel 0.07, velvet 0.05, tick 0.05, tennis_ball 0.04, vulture 0.04, 0.2ms
# 116: 224x224 paper_towel 0.10, velvet 0.06, dishrag 0.04, tick 0.04, tennis_ball 0.03, 0.2ms
# 117: 224x224 dishrag 0.07, paper_towel 0.06, tennis_ball 0.05, velvet 0.05, cardigan 0.04, 0.2ms
# 118: 224x224 tennis_ball 0.06, velvet 0.04, paper_towel 0.04, screw 0.04, tick 0.03, 0.2ms
# 119: 224x224 paper_towel 0.08, dishrag 0.07, velvet 0.06, tennis_ball 0.06, cardigan 0.04, 0.2ms
# 120: 224x224 tennis_ball 0.06, paper_towel 0.06, velvet 0.06, dishrag 0.05, screw 0.02, 0.2ms
# 121: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.05, tennis_ball 0.05, vulture 0.03, 0.2ms
# 122: 224x224 dishrag 0.08, velvet 0.06, paper_towel 0.05, tennis_ball 0.04, tick 0.03, 0.2ms
# 123: 224x224 paper_towel 0.07, velvet 0.06, tennis_ball 0.04, tick 0.04, vulture 0.03, 0.2ms
# 124: 224x224 paper_towel 0.09, tennis_ball 0.05, velvet 0.04, tick 0.03, screw 0.03, 0.2ms
# 125: 224x224 paper_towel 0.07, tennis_ball 0.05, dishrag 0.04, velvet 0.04, vulture 0.03, 0.2ms
# 126: 224x224 dishrag 0.07, tennis_ball 0.06, velvet 0.06, paper_towel 0.05, wool 0.03, 0.2ms
# 127: 224x224 paper_towel 0.07, tennis_ball 0.07, velvet 0.04, vulture 0.03, dishrag 0.03, 0.2ms
# 128: 224x224 paper_towel 0.08, tennis_ball 0.06, dishrag 0.05, velvet 0.04, tick 0.03, 0.2ms
# 129: 224x224 dishrag 0.06, tennis_ball 0.05, velvet 0.05, paper_towel 0.04, tick 0.03, 0.2ms
# 130: 224x224 paper_towel 0.06, velvet 0.06, dishrag 0.05, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 131: 224x224 paper_towel 0.07, velvet 0.07, dishrag 0.05, tennis_ball 0.04, tick 0.04, 0.2ms
# 132: 224x224 velvet 0.08, dishrag 0.06, paper_towel 0.05, tick 0.04, vulture 0.03, 0.2ms
# 133: 224x224 paper_towel 0.08, tennis_ball 0.05, velvet 0.05, dishrag 0.03, cardigan 0.03, 0.2ms
# 134: 224x224 dishrag 0.07, paper_towel 0.05, tennis_ball 0.05, velvet 0.05, tick 0.03, 0.2ms
# 135: 224x224 velvet 0.07, dishrag 0.07, paper_towel 0.06, tennis_ball 0.03, cardigan 0.03, 0.2ms
# 136: 224x224 dishrag 0.08, paper_towel 0.07, tennis_ball 0.06, velvet 0.04, stole 0.03, 0.2ms
# 137: 224x224 dishrag 0.07, velvet 0.06, tennis_ball 0.06, paper_towel 0.05, vulture 0.03, 0.2ms
# 138: 224x224 velvet 0.09, paper_towel 0.06, tennis_ball 0.05, dishrag 0.04, screw 0.03, 0.2ms
# 139: 224x224 paper_towel 0.06, velvet 0.06, tennis_ball 0.05, dishrag 0.03, vulture 0.03, 0.2ms
# 140: 224x224 dishrag 0.08, paper_towel 0.08, velvet 0.05, tennis_ball 0.04, bubble 0.03, 0.2ms
# 141: 224x224 velvet 0.06, tennis_ball 0.06, dishrag 0.06, paper_towel 0.04, screw 0.03, 0.2ms
# 142: 224x224 paper_towel 0.08, dishrag 0.05, tennis_ball 0.04, velvet 0.04, bubble 0.03, 0.2ms
# 143: 224x224 dishrag 0.08, paper_towel 0.07, velvet 0.06, tick 0.04, tennis_ball 0.03, 0.2ms
# 144: 224x224 dishrag 0.10, paper_towel 0.08, velvet 0.06, tennis_ball 0.05, wool 0.03, 0.2ms
# 145: 224x224 velvet 0.08, paper_towel 0.08, dishrag 0.05, tick 0.04, vulture 0.04, 0.2ms
# 146: 224x224 paper_towel 0.06, tennis_ball 0.04, velvet 0.04, vulture 0.04, tick 0.04, 0.2ms
# 147: 224x224 paper_towel 0.07, tennis_ball 0.05, dishrag 0.04, velvet 0.04, vulture 0.03, 0.2ms
# 148: 224x224 tennis_ball 0.06, paper_towel 0.06, velvet 0.05, dishrag 0.03, screw 0.03, 0.2ms
# 149: 224x224 dishrag 0.09, paper_towel 0.07, velvet 0.04, tennis_ball 0.04, stole 0.04, 0.2ms
# 150: 224x224 paper_towel 0.08, dishrag 0.06, velvet 0.05, tennis_ball 0.04, bubble 0.04, 0.2ms
# 151: 224x224 paper_towel 0.05, tennis_ball 0.05, velvet 0.05, dishrag 0.04, vulture 0.02, 0.2ms
# 152: 224x224 paper_towel 0.08, velvet 0.05, dishrag 0.05, tick 0.04, tennis_ball 0.03, 0.2ms
# 153: 224x224 paper_towel 0.08, velvet 0.06, tennis_ball 0.06, dishrag 0.03, cardigan 0.03, 0.2ms
# 154: 224x224 paper_towel 0.08, tennis_ball 0.05, velvet 0.05, vulture 0.04, dishrag 0.04, 0.2ms
# 155: 224x224 tennis_ball 0.05, paper_towel 0.05, dishrag 0.05, velvet 0.04, cardigan 0.03, 0.2ms
# 156: 224x224 dishrag 0.07, tennis_ball 0.05, paper_towel 0.05, velvet 0.04, vulture 0.03, 0.2ms
# 157: 224x224 dishrag 0.07, paper_towel 0.06, velvet 0.04, tick 0.03, tennis_ball 0.03, 0.2ms
# 158: 224x224 paper_towel 0.06, tennis_ball 0.05, velvet 0.04, dishrag 0.04, vulture 0.03, 0.2ms
# 159: 224x224 paper_towel 0.09, velvet 0.04, dishrag 0.04, vulture 0.04, tennis_ball 0.04, 0.2ms
# 160: 224x224 paper_towel 0.08, velvet 0.06, tennis_ball 0.05, vulture 0.04, dishrag 0.03, 0.2ms
# 161: 224x224 dishrag 0.10, velvet 0.06, paper_towel 0.05, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 162: 224x224 dishrag 0.10, paper_towel 0.08, velvet 0.07, tennis_ball 0.05, wool 0.03, 0.2ms
# 163: 224x224 paper_towel 0.07, tennis_ball 0.05, velvet 0.04, dishrag 0.03, tick 0.03, 0.2ms
# 164: 224x224 dishrag 0.18, paper_towel 0.06, velvet 0.05, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 165: 224x224 paper_towel 0.05, velvet 0.04, dishrag 0.04, tennis_ball 0.04, vulture 0.03, 0.2ms
# 166: 224x224 dishrag 0.09, paper_towel 0.08, velvet 0.06, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 167: 224x224 dishrag 0.23, paper_towel 0.06, velvet 0.05, cardigan 0.05, stole 0.04, 0.2ms
# 168: 224x224 paper_towel 0.06, vulture 0.04, tennis_ball 0.04, tick 0.03, velvet 0.03, 0.2ms
# 169: 224x224 paper_towel 0.06, tennis_ball 0.04, dishrag 0.04, velvet 0.04, tick 0.03, 0.2ms
# 170: 224x224 velvet 0.06, paper_towel 0.05, tennis_ball 0.04, tick 0.04, vulture 0.04, 0.2ms
# 171: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.06, tennis_ball 0.06, wool 0.03, 0.2ms
# 172: 224x224 dishrag 0.08, tennis_ball 0.06, paper_towel 0.06, velvet 0.05, wing 0.04, 0.2ms
# 173: 224x224 paper_towel 0.09, dishrag 0.07, tennis_ball 0.05, velvet 0.03, cardigan 0.03, 0.2ms
# 174: 224x224 paper_towel 0.08, dishrag 0.06, tennis_ball 0.05, velvet 0.05, cardigan 0.03, 0.2ms
# 175: 224x224 dishrag 0.15, paper_towel 0.07, velvet 0.06, vulture 0.04, tennis_ball 0.03, 0.2ms
# 176: 224x224 paper_towel 0.07, dishrag 0.06, tennis_ball 0.05, velvet 0.05, cardigan 0.03, 0.2ms
# 177: 224x224 paper_towel 0.08, velvet 0.06, dishrag 0.05, tennis_ball 0.04, bubble 0.03, 0.2ms
# 178: 224x224 dishrag 0.09, paper_towel 0.07, tennis_ball 0.05, velvet 0.03, vulture 0.03, 0.2ms
# 179: 224x224 paper_towel 0.08, velvet 0.05, tennis_ball 0.04, vulture 0.04, tick 0.04, 0.2ms
# 180: 224x224 paper_towel 0.06, vulture 0.05, tennis_ball 0.05, velvet 0.04, tick 0.03, 0.2ms
# 181: 224x224 velvet 0.07, dishrag 0.07, paper_towel 0.05, tennis_ball 0.04, tick 0.04, 0.2ms
# 182: 224x224 velvet 0.07, paper_towel 0.06, dishrag 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 183: 224x224 dishrag 0.06, paper_towel 0.05, velvet 0.05, tennis_ball 0.05, vulture 0.03, 0.2ms
# 184: 224x224 tennis_ball 0.06, paper_towel 0.06, dishrag 0.05, velvet 0.04, cardigan 0.03, 0.2ms
# 185: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.06, tennis_ball 0.04, tick 0.03, 0.2ms
# 186: 224x224 dishrag 0.08, paper_towel 0.07, tennis_ball 0.05, velvet 0.04, cardigan 0.04, 0.2ms
# 187: 224x224 paper_towel 0.07, tennis_ball 0.05, velvet 0.04, dishrag 0.03, vulture 0.03, 0.2ms
# 188: 224x224 paper_towel 0.08, velvet 0.06, dishrag 0.05, tennis_ball 0.04, vulture 0.03, 0.2ms
# 189: 224x224 dishrag 0.07, paper_towel 0.07, velvet 0.06, tennis_ball 0.04, tick 0.04, 0.2ms
# 190: 224x224 paper_towel 0.06, velvet 0.05, tennis_ball 0.04, vulture 0.04, dishrag 0.04, 0.2ms
# 191: 224x224 paper_towel 0.07, velvet 0.05, dishrag 0.04, vulture 0.04, tennis_ball 0.03, 0.2ms
# 192: 224x224 paper_towel 0.06, velvet 0.06, dishrag 0.05, tennis_ball 0.04, vulture 0.03, 0.2ms
# 193: 224x224 tennis_ball 0.06, velvet 0.05, paper_towel 0.05, dishrag 0.04, vulture 0.04, 0.2ms
# 194: 224x224 paper_towel 0.08, velvet 0.05, tennis_ball 0.04, dishrag 0.03, vulture 0.03, 0.2ms
# 195: 224x224 paper_towel 0.06, dishrag 0.05, tennis_ball 0.05, velvet 0.04, cardigan 0.03, 0.2ms
# 196: 224x224 dishrag 0.08, paper_towel 0.06, tennis_ball 0.05, velvet 0.04, cardigan 0.03, 0.2ms
# 197: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.06, vulture 0.04, dishrag 0.03, 0.2ms
# 198: 224x224 paper_towel 0.07, dishrag 0.07, velvet 0.05, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 199: 224x224 paper_towel 0.06, tennis_ball 0.06, dishrag 0.05, velvet 0.04, vulture 0.03, 0.2ms
# 200: 224x224 dishrag 0.11, paper_towel 0.08, velvet 0.05, tick 0.03, wool 0.03, 0.2ms
# 201: 224x224 paper_towel 0.06, tennis_ball 0.05, velvet 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 202: 224x224 dishrag 0.07, tennis_ball 0.06, velvet 0.05, paper_towel 0.05, tick 0.03, 0.2ms
# 203: 224x224 paper_towel 0.09, dishrag 0.08, velvet 0.06, tennis_ball 0.04, tick 0.04, 0.2ms
# 204: 224x224 paper_towel 0.10, dishrag 0.07, velvet 0.06, tennis_ball 0.04, tick 0.03, 0.2ms
# 205: 224x224 velvet 0.06, paper_towel 0.05, tennis_ball 0.05, dishrag 0.05, vulture 0.03, 0.2ms
# 206: 224x224 paper_towel 0.06, velvet 0.05, dishrag 0.05, tennis_ball 0.05, vulture 0.03, 0.2ms
# 207: 224x224 paper_towel 0.07, dishrag 0.06, tennis_ball 0.05, velvet 0.03, cardigan 0.03, 0.2ms
# 208: 224x224 paper_towel 0.10, dishrag 0.06, velvet 0.05, tennis_ball 0.05, wool 0.03, 0.2ms
# 209: 224x224 paper_towel 0.09, dishrag 0.06, velvet 0.05, tennis_ball 0.04, tick 0.03, 0.2ms
# 210: 224x224 dishrag 0.05, velvet 0.05, paper_towel 0.04, tennis_ball 0.04, tick 0.03, 0.2ms
# 211: 224x224 tennis_ball 0.06, dishrag 0.06, velvet 0.06, paper_towel 0.05, tick 0.03, 0.2ms
# 212: 224x224 dishrag 0.13, velvet 0.06, tennis_ball 0.04, paper_towel 0.04, wool 0.04, 0.2ms
# 213: 224x224 tennis_ball 0.05, paper_towel 0.04, velvet 0.04, screw 0.04, tick 0.04, 0.2ms
# 214: 224x224 paper_towel 0.08, dishrag 0.06, velvet 0.05, tennis_ball 0.04, tick 0.03, 0.2ms
# 215: 224x224 paper_towel 0.09, velvet 0.06, dishrag 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 216: 224x224 velvet 0.07, paper_towel 0.05, tennis_ball 0.05, vulture 0.03, dishrag 0.03, 0.2ms
# 217: 224x224 paper_towel 0.09, dishrag 0.07, tennis_ball 0.06, velvet 0.04, tick 0.03, 0.2ms
# 218: 224x224 paper_towel 0.09, dishrag 0.05, velvet 0.05, tennis_ball 0.03, tick 0.03, 0.2ms
# 219: 224x224 paper_towel 0.08, tennis_ball 0.05, velvet 0.05, tick 0.03, dishrag 0.03, 0.2ms
# 220: 224x224 paper_towel 0.08, dishrag 0.07, velvet 0.05, tennis_ball 0.05, vulture 0.03, 0.2ms
# 221: 224x224 paper_towel 0.07, dishrag 0.07, velvet 0.04, tennis_ball 0.04, tick 0.04, 0.2ms
# 222: 224x224 tennis_ball 0.06, paper_towel 0.06, velvet 0.05, vulture 0.04, tick 0.04, 0.2ms
# 223: 224x224 paper_towel 0.06, dishrag 0.06, tennis_ball 0.05, velvet 0.04, tick 0.02, 0.2ms
# 224: 224x224 dishrag 0.08, paper_towel 0.08, tick 0.05, velvet 0.05, vulture 0.04, 0.2ms
# 225: 224x224 velvet 0.05, paper_towel 0.05, tennis_ball 0.05, dishrag 0.05, vulture 0.03, 0.2ms
# 226: 224x224 paper_towel 0.07, tick 0.05, velvet 0.05, vulture 0.05, tennis_ball 0.04, 0.2ms
# 227: 224x224 paper_towel 0.07, velvet 0.05, tennis_ball 0.04, dishrag 0.04, vulture 0.03, 0.2ms
# 228: 224x224 dishrag 0.09, paper_towel 0.07, tennis_ball 0.06, velvet 0.05, cardigan 0.04, 0.2ms
# 229: 224x224 dishrag 0.14, velvet 0.12, paper_towel 0.06, cardigan 0.03, tick 0.03, 0.2ms
# 230: 224x224 paper_towel 0.07, velvet 0.05, tennis_ball 0.04, dishrag 0.04, tick 0.03, 0.2ms
# 231: 224x224 tennis_ball 0.06, velvet 0.05, vulture 0.05, paper_towel 0.04, tick 0.03, 0.2ms
# 232: 224x224 dishrag 0.10, paper_towel 0.07, velvet 0.06, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 233: 224x224 tennis_ball 0.06, dishrag 0.05, paper_towel 0.05, velvet 0.04, cardigan 0.03, 0.2ms
# 234: 224x224 paper_towel 0.06, velvet 0.05, tennis_ball 0.04, tick 0.03, dishrag 0.03, 0.2ms
# 235: 224x224 paper_towel 0.06, velvet 0.05, tennis_ball 0.05, tick 0.04, vulture 0.03, 0.2ms
# 236: 224x224 paper_towel 0.06, tennis_ball 0.06, velvet 0.05, dishrag 0.05, vulture 0.03, 0.2ms
# 237: 224x224 paper_towel 0.06, tennis_ball 0.05, dishrag 0.05, velvet 0.04, screw 0.02, 0.2ms
# 238: 224x224 velvet 0.06, paper_towel 0.05, tennis_ball 0.05, vulture 0.04, dishrag 0.03, 0.2ms
# 239: 224x224 paper_towel 0.08, dishrag 0.08, velvet 0.05, tennis_ball 0.04, bubble 0.03, 0.2ms
# 240: 224x224 paper_towel 0.06, velvet 0.06, dishrag 0.06, tennis_ball 0.04, vulture 0.03, 0.2ms
# 241: 224x224 paper_towel 0.07, dishrag 0.05, velvet 0.05, tick 0.05, tennis_ball 0.04, 0.2ms
# 242: 224x224 paper_towel 0.09, tennis_ball 0.05, velvet 0.05, dishrag 0.04, vulture 0.04, 0.2ms
# 243: 224x224 paper_towel 0.06, tennis_ball 0.05, velvet 0.05, tick 0.04, vulture 0.04, 0.2ms
# 244: 224x224 dishrag 0.07, paper_towel 0.06, velvet 0.05, tennis_ball 0.05, wool 0.03, 0.2ms
# 245: 224x224 paper_towel 0.08, dishrag 0.07, velvet 0.05, tennis_ball 0.05, bubble 0.03, 0.2ms
# 246: 224x224 dishrag 0.07, tennis_ball 0.05, velvet 0.05, paper_towel 0.05, cardigan 0.03, 0.2ms
# 247: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.04, tennis_ball 0.03, tick 0.03, 0.2ms
# 248: 224x224 tennis_ball 0.06, paper_towel 0.05, velvet 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 249: 224x224 dishrag 0.10, velvet 0.07, paper_towel 0.07, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 250: 224x224 paper_towel 0.07, velvet 0.05, dishrag 0.05, tennis_ball 0.04, tick 0.03, 0.2ms
# 251: 224x224 paper_towel 0.08, velvet 0.05, tennis_ball 0.05, dishrag 0.04, vulture 0.04, 0.2ms
# 252: 224x224 paper_towel 0.09, velvet 0.04, tennis_ball 0.04, dishrag 0.04, tick 0.04, 0.2ms
# 253: 224x224 dishrag 0.06, paper_towel 0.05, tennis_ball 0.05, velvet 0.05, vulture 0.03, 0.2ms
# 254: 224x224 paper_towel 0.09, dishrag 0.07, velvet 0.04, tennis_ball 0.04, tick 0.03, 0.2ms
# 255: 224x224 velvet 0.08, paper_towel 0.06, dishrag 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 256: 224x224 velvet 0.06, paper_towel 0.06, tennis_ball 0.05, tick 0.04, vulture 0.04, 0.2ms
# 257: 224x224 paper_towel 0.06, velvet 0.06, tennis_ball 0.04, dishrag 0.04, tick 0.03, 0.2ms
# 258: 224x224 paper_towel 0.07, velvet 0.07, dishrag 0.05, tennis_ball 0.05, vulture 0.04, 0.2ms
# 259: 224x224 velvet 0.07, dishrag 0.07, paper_towel 0.06, tennis_ball 0.03, tick 0.03, 0.2ms
# 260: 224x224 paper_towel 0.06, dishrag 0.06, tennis_ball 0.05, velvet 0.04, vulture 0.03, 0.2ms
# 261: 224x224 paper_towel 0.06, velvet 0.06, dishrag 0.05, tennis_ball 0.04, vulture 0.04, 0.2ms
# 262: 224x224 paper_towel 0.07, velvet 0.06, tennis_ball 0.05, tick 0.04, dishrag 0.03, 0.2ms
# 263: 224x224 dishrag 0.07, paper_towel 0.06, tennis_ball 0.04, velvet 0.04, cardigan 0.03, 0.2ms
# 264: 224x224 paper_towel 0.06, velvet 0.05, tennis_ball 0.05, dishrag 0.04, bubble 0.03, 0.2ms
# 265: 224x224 dishrag 0.13, velvet 0.04, paper_towel 0.04, tennis_ball 0.03, vulture 0.03, 0.2ms
# 266: 224x224 paper_towel 0.07, dishrag 0.05, velvet 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 267: 224x224 dishrag 0.08, paper_towel 0.08, velvet 0.06, cardigan 0.04, tennis_ball 0.04, 0.2ms
# 268: 224x224 dishrag 0.11, paper_towel 0.07, velvet 0.06, cardigan 0.06, tennis_ball 0.04, 0.2ms
# 269: 224x224 paper_towel 0.07, velvet 0.06, dishrag 0.06, tennis_ball 0.05, tick 0.03, 0.2ms
# 270: 224x224 tennis_ball 0.07, paper_towel 0.06, velvet 0.05, dishrag 0.04, vulture 0.03, 0.2ms
# 271: 224x224 paper_towel 0.06, tennis_ball 0.05, velvet 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 272: 224x224 paper_towel 0.07, velvet 0.07, tennis_ball 0.06, dishrag 0.05, tick 0.04, 0.2ms
# 273: 224x224 dishrag 0.07, paper_towel 0.06, tennis_ball 0.05, velvet 0.04, cardigan 0.03, 0.2ms
# 274: 224x224 tennis_ball 0.05, paper_towel 0.05, velvet 0.05, tick 0.03, vulture 0.03, 0.2ms
# 275: 224x224 paper_towel 0.08, velvet 0.06, dishrag 0.06, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 276: 224x224 velvet 0.09, paper_towel 0.07, tennis_ball 0.06, dishrag 0.06, tick 0.04, 0.2ms
# 277: 224x224 paper_towel 0.06, tennis_ball 0.06, velvet 0.05, tick 0.04, dishrag 0.03, 0.2ms
# 278: 224x224 tennis_ball 0.06, velvet 0.05, paper_towel 0.05, dishrag 0.04, vulture 0.03, 0.2ms
# 279: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.05, dishrag 0.04, screw 0.03, 0.2ms
# 280: 224x224 paper_towel 0.08, velvet 0.06, dishrag 0.06, tennis_ball 0.05, bubble 0.03, 0.2ms
# 281: 224x224 dishrag 0.10, paper_towel 0.06, velvet 0.06, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 282: 224x224 velvet 0.06, paper_towel 0.05, dishrag 0.05, tennis_ball 0.05, vulture 0.04, 0.2ms
# 283: 224x224 paper_towel 0.07, velvet 0.04, tennis_ball 0.04, dishrag 0.04, screw 0.03, 0.2ms
# 284: 224x224 paper_towel 0.08, tennis_ball 0.05, dishrag 0.04, velvet 0.04, tick 0.03, 0.2ms
# 285: 224x224 paper_towel 0.07, velvet 0.05, dishrag 0.04, tennis_ball 0.04, screw 0.02, 0.2ms
# 286: 224x224 dishrag 0.10, velvet 0.06, paper_towel 0.05, tennis_ball 0.04, vulture 0.03, 0.2ms
# 287: 224x224 tennis_ball 0.07, paper_towel 0.06, velvet 0.05, dishrag 0.04, bubble 0.03, 0.2ms
# 288: 224x224 tennis_ball 0.06, dishrag 0.06, velvet 0.06, paper_towel 0.05, cardigan 0.03, 0.2ms
# 289: 224x224 dishrag 0.09, velvet 0.06, tennis_ball 0.05, paper_towel 0.04, cardigan 0.03, 0.2ms
# 290: 224x224 tennis_ball 0.06, paper_towel 0.05, velvet 0.05, dishrag 0.04, screw 0.03, 0.2ms
# 291: 224x224 dishrag 0.07, velvet 0.06, tennis_ball 0.05, paper_towel 0.05, tick 0.03, 0.2ms
# 292: 224x224 velvet 0.06, tennis_ball 0.05, dishrag 0.05, paper_towel 0.05, vulture 0.03, 0.2ms
# 293: 224x224 dishrag 0.07, paper_towel 0.07, velvet 0.06, tennis_ball 0.05, tick 0.03, 0.2ms
# 294: 224x224 paper_towel 0.10, dishrag 0.08, velvet 0.05, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 295: 224x224 dishrag 0.09, paper_towel 0.07, velvet 0.06, tennis_ball 0.05, vulture 0.03, 0.2ms
# 296: 224x224 dishrag 0.10, paper_towel 0.06, velvet 0.06, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 297: 224x224 tennis_ball 0.07, paper_towel 0.07, velvet 0.05, dishrag 0.05, cardigan 0.03, 0.2ms
# 298: 224x224 paper_towel 0.08, tennis_ball 0.05, dishrag 0.05, velvet 0.04, bubble 0.03, 0.2ms
# 299: 224x224 paper_towel 0.08, velvet 0.07, tick 0.04, vulture 0.04, dishrag 0.04, 0.2ms
# 300: 224x224 paper_towel 0.07, dishrag 0.05, tennis_ball 0.05, velvet 0.04, bubble 0.03, 0.2ms
# 301: 224x224 paper_towel 0.07, velvet 0.05, tennis_ball 0.05, dishrag 0.04, vulture 0.02, 0.2ms
# 302: 224x224 paper_towel 0.07, velvet 0.06, dishrag 0.05, tennis_ball 0.04, vulture 0.04, 0.2ms
# 303: 224x224 dishrag 0.13, velvet 0.07, paper_towel 0.06, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 304: 224x224 paper_towel 0.07, dishrag 0.07, velvet 0.06, tennis_ball 0.06, cardigan 0.04, 0.2ms
# 305: 224x224 paper_towel 0.05, velvet 0.05, dishrag 0.05, tennis_ball 0.05, bubble 0.03, 0.2ms
# 306: 224x224 velvet 0.06, paper_towel 0.05, tennis_ball 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 307: 224x224 dishrag 0.08, paper_towel 0.08, velvet 0.06, tennis_ball 0.04, vulture 0.03, 0.2ms
# 308: 224x224 dishrag 0.09, paper_towel 0.08, velvet 0.06, tennis_ball 0.03, tick 0.03, 0.2ms
# 309: 224x224 paper_towel 0.09, velvet 0.09, dishrag 0.07, tick 0.04, vulture 0.03, 0.2ms
# 310: 224x224 paper_towel 0.06, tennis_ball 0.05, dishrag 0.04, velvet 0.04, cardigan 0.03, 0.2ms
# 311: 224x224 paper_towel 0.07, velvet 0.07, dishrag 0.06, tennis_ball 0.05, vulture 0.03, 0.2ms
# 312: 224x224 dishrag 0.11, paper_towel 0.06, tennis_ball 0.05, velvet 0.05, vulture 0.03, 0.2ms
# 313: 224x224 paper_towel 0.08, dishrag 0.07, tennis_ball 0.06, velvet 0.06, wool 0.03, 0.2ms
# 314: 224x224 dishrag 0.08, paper_towel 0.07, velvet 0.06, tennis_ball 0.04, vulture 0.04, 0.2ms
# 315: 224x224 velvet 0.07, paper_towel 0.07, tick 0.04, tennis_ball 0.04, dishrag 0.03, 0.2ms
# 316: 224x224 paper_towel 0.08, tennis_ball 0.06, velvet 0.04, dishrag 0.04, tick 0.03, 0.2ms
# 317: 224x224 dishrag 0.06, tennis_ball 0.05, paper_towel 0.05, velvet 0.04, cardigan 0.03, 0.2ms
# 318: 224x224 paper_towel 0.06, tennis_ball 0.06, vulture 0.04, velvet 0.04, tick 0.04, 0.2ms
# 319: 224x224 velvet 0.06, paper_towel 0.06, dishrag 0.05, tennis_ball 0.04, tick 0.03, 0.2ms
# 320: 224x224 dishrag 0.06, tennis_ball 0.05, paper_towel 0.05, velvet 0.04, screw 0.03, 0.2ms
# 321: 224x224 paper_towel 0.06, dishrag 0.05, tennis_ball 0.05, velvet 0.04, tick 0.03, 0.2ms
# 322: 224x224 velvet 0.07, paper_towel 0.07, dishrag 0.06, bubble 0.05, stole 0.03, 0.2ms
# 323: 224x224 dishrag 0.08, velvet 0.06, paper_towel 0.06, tennis_ball 0.03, tick 0.03, 0.2ms
# 324: 224x224 paper_towel 0.05, tennis_ball 0.05, velvet 0.04, vulture 0.04, tick 0.03, 0.2ms
# 325: 224x224 dishrag 0.09, paper_towel 0.06, velvet 0.06, tennis_ball 0.04, cardigan 0.04, 0.2ms
# 326: 224x224 paper_towel 0.06, velvet 0.05, tennis_ball 0.05, dishrag 0.04, vulture 0.04, 0.2ms
# 327: 224x224 dishrag 0.07, velvet 0.07, paper_towel 0.06, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 328: 224x224 tennis_ball 0.06, velvet 0.05, paper_towel 0.04, dishrag 0.04, screw 0.04, 0.2ms
# 329: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.05, tennis_ball 0.04, vulture 0.03, 0.2ms
# 330: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.05, tick 0.04, tennis_ball 0.03, 0.2ms
# 331: 224x224 paper_towel 0.09, velvet 0.05, tennis_ball 0.04, dishrag 0.04, tick 0.04, 0.2ms
# 332: 224x224 paper_towel 0.08, dishrag 0.08, velvet 0.06, tennis_ball 0.05, cardigan 0.04, 0.2ms
# 333: 224x224 dishrag 0.09, paper_towel 0.07, tennis_ball 0.05, velvet 0.04, cardigan 0.04, 0.2ms
# 334: 224x224 dishrag 0.09, velvet 0.08, paper_towel 0.07, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 335: 224x224 dishrag 0.07, paper_towel 0.07, velvet 0.05, tennis_ball 0.04, vulture 0.03, 0.2ms
# 336: 224x224 paper_towel 0.09, velvet 0.07, dishrag 0.06, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 337: 224x224 paper_towel 0.06, dishrag 0.05, velvet 0.05, tennis_ball 0.05, vulture 0.04, 0.2ms
# 338: 224x224 dishrag 0.08, velvet 0.06, paper_towel 0.06, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 339: 224x224 dishrag 0.08, paper_towel 0.07, velvet 0.06, tennis_ball 0.03, cardigan 0.03, 0.2ms
# 340: 224x224 paper_towel 0.09, tennis_ball 0.05, velvet 0.05, dishrag 0.05, tick 0.03, 0.2ms
# 341: 224x224 paper_towel 0.08, dishrag 0.05, velvet 0.04, tennis_ball 0.03, vulture 0.03, 0.2ms
# 342: 224x224 dishrag 0.09, paper_towel 0.09, velvet 0.06, tennis_ball 0.03, cardigan 0.03, 0.2ms
# 343: 224x224 dishrag 0.11, paper_towel 0.06, velvet 0.05, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 344: 224x224 tennis_ball 0.06, paper_towel 0.06, dishrag 0.05, velvet 0.05, cardigan 0.03, 0.2ms
# 345: 224x224 paper_towel 0.08, velvet 0.07, tennis_ball 0.05, dishrag 0.04, vulture 0.04, 0.2ms
# 346: 224x224 paper_towel 0.07, tennis_ball 0.05, velvet 0.05, dishrag 0.05, tick 0.03, 0.2ms
# 347: 224x224 dishrag 0.16, velvet 0.06, paper_towel 0.06, tennis_ball 0.04, stole 0.04, 0.2ms
# 348: 224x224 dishrag 0.11, velvet 0.07, tennis_ball 0.06, paper_towel 0.04, cardigan 0.03, 0.2ms
# 349: 224x224 tennis_ball 0.06, dishrag 0.06, velvet 0.05, paper_towel 0.04, vulture 0.03, 0.2ms
# 350: 224x224 paper_towel 0.07, tennis_ball 0.05, tick 0.05, vulture 0.05, velvet 0.04, 0.2ms
# 351: 224x224 dishrag 0.07, paper_towel 0.05, velvet 0.05, tennis_ball 0.05, vulture 0.03, 0.2ms
# 352: 224x224 dishrag 0.06, velvet 0.05, paper_towel 0.05, tennis_ball 0.05, vulture 0.03, 0.2ms
# 353: 224x224 paper_towel 0.07, tennis_ball 0.06, dishrag 0.05, velvet 0.04, screw 0.03, 0.2ms
# 354: 224x224 paper_towel 0.09, dishrag 0.08, velvet 0.07, tennis_ball 0.05, tick 0.03, 0.2ms
# 355: 224x224 dishrag 0.13, paper_towel 0.07, velvet 0.06, tennis_ball 0.04, wool 0.03, 0.2ms
# 356: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.04, tennis_ball 0.04, vulture 0.03, 0.2ms
# 357: 224x224 paper_towel 0.07, velvet 0.06, tennis_ball 0.05, vulture 0.04, tick 0.03, 0.2ms
# 358: 224x224 dishrag 0.08, paper_towel 0.08, velvet 0.05, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 359: 224x224 dishrag 0.12, paper_towel 0.06, velvet 0.05, stole 0.04, tennis_ball 0.04, 0.2ms
# 360: 224x224 velvet 0.07, paper_towel 0.06, dishrag 0.06, tennis_ball 0.04, vulture 0.03, 0.2ms
# 361: 224x224 dishrag 0.08, velvet 0.06, tennis_ball 0.05, paper_towel 0.05, cardigan 0.03, 0.2ms
# 362: 224x224 dishrag 0.11, tennis_ball 0.08, paper_towel 0.06, velvet 0.05, cardigan 0.03, 0.2ms
# 363: 224x224 dishrag 0.11, velvet 0.07, paper_towel 0.05, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 364: 224x224 tennis_ball 0.07, paper_towel 0.05, velvet 0.04, dishrag 0.04, screw 0.03, 0.2ms
# 365: 224x224 dishrag 0.07, paper_towel 0.06, velvet 0.05, tennis_ball 0.04, bubble 0.04, 0.2ms
# 366: 224x224 paper_towel 0.06, velvet 0.06, tennis_ball 0.04, dishrag 0.04, tick 0.03, 0.2ms
# 367: 224x224 paper_towel 0.07, dishrag 0.07, velvet 0.06, tennis_ball 0.05, bubble 0.03, 0.2ms
# 368: 224x224 velvet 0.07, paper_towel 0.05, tennis_ball 0.05, tick 0.04, dishrag 0.03, 0.2ms
# 369: 224x224 paper_towel 0.06, velvet 0.06, tick 0.05, vulture 0.04, dishrag 0.04, 0.2ms
# 370: 224x224 velvet 0.08, dishrag 0.07, paper_towel 0.07, tennis_ball 0.04, tick 0.03, 0.2ms
# 371: 224x224 dishrag 0.05, tennis_ball 0.05, velvet 0.04, paper_towel 0.04, vulture 0.04, 0.2ms
# 372: 224x224 velvet 0.09, dishrag 0.07, paper_towel 0.07, tennis_ball 0.04, tick 0.03, 0.2ms
# 373: 224x224 dishrag 0.08, paper_towel 0.06, velvet 0.05, tennis_ball 0.05, vulture 0.03, 0.2ms
# 374: 224x224 dishrag 0.07, velvet 0.06, paper_towel 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 375: 224x224 dishrag 0.12, paper_towel 0.08, velvet 0.06, cardigan 0.04, tennis_ball 0.04, 0.2ms
# 376: 224x224 paper_towel 0.09, tennis_ball 0.06, dishrag 0.05, velvet 0.04, cardigan 0.03, 0.2ms
# 377: 224x224 velvet 0.07, paper_towel 0.06, tennis_ball 0.05, dishrag 0.04, tick 0.04, 0.2ms
# 378: 224x224 paper_towel 0.08, dishrag 0.07, velvet 0.05, tennis_ball 0.04, cardigan 0.04, 0.2ms
# 379: 224x224 paper_towel 0.06, velvet 0.06, tennis_ball 0.05, vulture 0.04, dishrag 0.04, 0.2ms
# 380: 224x224 velvet 0.06, paper_towel 0.06, tennis_ball 0.06, dishrag 0.03, tick 0.03, 0.2ms
# 381: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 382: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.05, dishrag 0.04, vulture 0.03, 0.2ms
# 383: 224x224 dishrag 0.10, paper_towel 0.05, velvet 0.05, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 384: 224x224 dishrag 0.08, paper_towel 0.08, tennis_ball 0.06, velvet 0.05, cardigan 0.03, 0.2ms
# 385: 224x224 dishrag 0.08, paper_towel 0.05, tennis_ball 0.05, velvet 0.04, cardigan 0.03, 0.2ms
# 386: 224x224 velvet 0.05, paper_towel 0.05, dishrag 0.04, tennis_ball 0.04, vulture 0.03, 0.2ms
# 387: 224x224 paper_towel 0.07, tennis_ball 0.05, velvet 0.04, dishrag 0.04, vulture 0.03, 0.2ms
# 388: 224x224 paper_towel 0.08, tennis_ball 0.06, dishrag 0.05, velvet 0.04, tick 0.03, 0.2ms
# 389: 224x224 paper_towel 0.07, dishrag 0.07, velvet 0.06, tennis_ball 0.03, bubble 0.03, 0.2ms
# 390: 224x224 paper_towel 0.08, dishrag 0.08, velvet 0.07, tennis_ball 0.04, wool 0.04, 0.2ms
# 391: 224x224 dishrag 0.11, paper_towel 0.08, velvet 0.05, tennis_ball 0.04, tick 0.03, 0.2ms
# 392: 224x224 dishrag 0.13, paper_towel 0.06, tennis_ball 0.05, velvet 0.04, cardigan 0.03, 0.2ms
# 393: 224x224 tennis_ball 0.06, dishrag 0.06, velvet 0.05, paper_towel 0.04, vulture 0.04, 0.2ms
# 394: 224x224 velvet 0.06, dishrag 0.05, paper_towel 0.05, tennis_ball 0.04, vulture 0.03, 0.2ms
# 395: 224x224 dishrag 0.08, tennis_ball 0.06, paper_towel 0.05, velvet 0.05, cardigan 0.03, 0.2ms
# 396: 224x224 paper_towel 0.09, velvet 0.07, tennis_ball 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 397: 224x224 dishrag 0.11, paper_towel 0.07, velvet 0.06, cardigan 0.04, tennis_ball 0.04, 0.2ms
# 398: 224x224 paper_towel 0.07, velvet 0.06, tennis_ball 0.05, dishrag 0.04, vulture 0.04, 0.2ms
# 399: 224x224 paper_towel 0.10, dishrag 0.05, tennis_ball 0.04, velvet 0.04, tick 0.03, 0.2ms
# 400: 224x224 velvet 0.07, paper_towel 0.05, dishrag 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 401: 224x224 paper_towel 0.06, tennis_ball 0.05, dishrag 0.05, velvet 0.05, tick 0.03, 0.2ms
# 402: 224x224 dishrag 0.09, velvet 0.06, paper_towel 0.06, stole 0.04, tennis_ball 0.04, 0.2ms
# 403: 224x224 velvet 0.06, tennis_ball 0.05, paper_towel 0.05, vulture 0.05, tick 0.04, 0.2ms
# 404: 224x224 paper_towel 0.08, velvet 0.05, tennis_ball 0.05, tick 0.03, screw 0.03, 0.2ms
# 405: 224x224 paper_towel 0.09, tick 0.04, velvet 0.04, tennis_ball 0.04, dishrag 0.04, 0.2ms
# 406: 224x224 paper_towel 0.08, velvet 0.07, dishrag 0.07, tennis_ball 0.06, tick 0.04, 0.2ms
# 407: 224x224 velvet 0.05, paper_towel 0.05, vulture 0.05, dishrag 0.04, tennis_ball 0.03, 0.2ms
# 408: 224x224 velvet 0.08, paper_towel 0.07, dishrag 0.06, cardigan 0.05, tennis_ball 0.05, 0.2ms
# 409: 224x224 vulture 0.05, tick 0.05, paper_towel 0.05, velvet 0.05, dishrag 0.03, 0.2ms
# 410: 224x224 velvet 0.06, paper_towel 0.06, dishrag 0.06, tennis_ball 0.04, vulture 0.03, 0.2ms
# 411: 224x224 dishrag 0.06, velvet 0.06, tennis_ball 0.05, paper_towel 0.04, tick 0.03, 0.2ms
# 412: 224x224 paper_towel 0.10, dishrag 0.08, velvet 0.06, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 413: 224x224 paper_towel 0.08, tennis_ball 0.06, velvet 0.05, dishrag 0.05, tick 0.03, 0.2ms
# 414: 224x224 vulture 0.06, tick 0.05, velvet 0.05, tennis_ball 0.05, paper_towel 0.05, 0.2ms
# 415: 224x224 paper_towel 0.09, velvet 0.05, tennis_ball 0.05, dishrag 0.05, cardigan 0.04, 0.2ms
# 416: 224x224 paper_towel 0.07, velvet 0.05, tennis_ball 0.05, tick 0.03, dishrag 0.03, 0.2ms
# 417: 224x224 dishrag 0.07, paper_towel 0.06, velvet 0.05, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 418: 224x224 tennis_ball 0.06, paper_towel 0.06, velvet 0.05, dishrag 0.03, cardigan 0.02, 0.2ms
# 419: 224x224 paper_towel 0.10, dishrag 0.08, velvet 0.04, tennis_ball 0.04, tick 0.03, 0.2ms
# 420: 224x224 paper_towel 0.07, tennis_ball 0.05, velvet 0.05, dishrag 0.03, tick 0.03, 0.2ms
# 421: 224x224 paper_towel 0.07, tennis_ball 0.06, vulture 0.04, velvet 0.04, tick 0.03, 0.2ms
# 422: 224x224 paper_towel 0.08, tennis_ball 0.05, dishrag 0.04, velvet 0.04, tick 0.03, 0.2ms
# 423: 224x224 paper_towel 0.07, tennis_ball 0.06, dishrag 0.04, velvet 0.04, cardigan 0.03, 0.2ms
# 424: 224x224 paper_towel 0.06, tennis_ball 0.06, dishrag 0.06, velvet 0.05, bubble 0.03, 0.2ms
# 425: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.05, dishrag 0.05, bubble 0.02, 0.2ms
# 426: 224x224 dishrag 0.08, paper_towel 0.08, velvet 0.06, tennis_ball 0.04, bubble 0.04, 0.2ms
# 427: 224x224 tennis_ball 0.06, velvet 0.05, paper_towel 0.04, dishrag 0.04, tick 0.04, 0.2ms
# 428: 224x224 paper_towel 0.05, velvet 0.05, tennis_ball 0.05, tick 0.03, dishrag 0.03, 0.2ms
# 429: 224x224 dishrag 0.13, velvet 0.07, paper_towel 0.07, tennis_ball 0.05, cardigan 0.04, 0.2ms
# 430: 224x224 velvet 0.06, paper_towel 0.06, dishrag 0.05, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 431: 224x224 dishrag 0.11, velvet 0.08, paper_towel 0.05, tennis_ball 0.04, wool 0.03, 0.2ms
# 432: 224x224 dishrag 0.07, paper_towel 0.06, velvet 0.05, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 433: 224x224 paper_towel 0.08, tennis_ball 0.06, velvet 0.04, dishrag 0.03, tick 0.03, 0.2ms
# 434: 224x224 paper_towel 0.07, velvet 0.07, tennis_ball 0.06, dishrag 0.04, vulture 0.03, 0.2ms
# 435: 224x224 tennis_ball 0.05, velvet 0.05, paper_towel 0.04, tick 0.04, screw 0.03, 0.2ms
# 436: 224x224 dishrag 0.10, velvet 0.07, paper_towel 0.05, tennis_ball 0.04, screw 0.03, 0.2ms
# 437: 224x224 tennis_ball 0.07, dishrag 0.06, paper_towel 0.05, velvet 0.05, tick 0.03, 0.2ms
# 438: 224x224 paper_towel 0.09, dishrag 0.09, velvet 0.04, tennis_ball 0.03, bubble 0.03, 0.2ms
# 439: 224x224 dishrag 0.06, tennis_ball 0.06, paper_towel 0.06, velvet 0.05, vulture 0.03, 0.2ms
# 440: 224x224 paper_towel 0.08, velvet 0.07, dishrag 0.06, tennis_ball 0.04, tick 0.03, 0.2ms
# 441: 224x224 dishrag 0.18, paper_towel 0.06, velvet 0.05, cardigan 0.04, wool 0.03, 0.2ms
# 442: 224x224 velvet 0.07, dishrag 0.05, paper_towel 0.05, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 443: 224x224 paper_towel 0.08, velvet 0.05, dishrag 0.04, tennis_ball 0.04, tick 0.04, 0.2ms
# 444: 224x224 paper_towel 0.06, tennis_ball 0.05, velvet 0.04, vulture 0.04, tick 0.03, 0.2ms
# 445: 224x224 paper_towel 0.08, dishrag 0.06, tennis_ball 0.05, velvet 0.05, tick 0.03, 0.2ms
# 446: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 447: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 448: 224x224 paper_towel 0.10, dishrag 0.07, velvet 0.04, tick 0.04, tennis_ball 0.03, 0.2ms
# 449: 224x224 velvet 0.07, tennis_ball 0.06, vulture 0.05, paper_towel 0.05, tick 0.03, 0.2ms
# 450: 224x224 paper_towel 0.09, dishrag 0.08, tennis_ball 0.06, velvet 0.05, wool 0.04, 0.2ms
# 451: 224x224 paper_towel 0.08, velvet 0.06, tennis_ball 0.05, tick 0.05, dishrag 0.04, 0.2ms
# 452: 224x224 paper_towel 0.09, dishrag 0.06, velvet 0.05, tennis_ball 0.05, tick 0.04, 0.2ms
# 453: 224x224 paper_towel 0.07, velvet 0.06, dishrag 0.04, tick 0.04, tennis_ball 0.04, 0.2ms
# 454: 224x224 dishrag 0.07, paper_towel 0.05, tennis_ball 0.04, velvet 0.04, cardigan 0.03, 0.2ms
# 455: 224x224 paper_towel 0.06, tennis_ball 0.06, dishrag 0.04, velvet 0.04, cardigan 0.03, 0.2ms
# 456: 224x224 paper_towel 0.12, dishrag 0.06, velvet 0.05, bubble 0.04, tennis_ball 0.04, 0.2ms
# 457: 224x224 paper_towel 0.07, tennis_ball 0.05, dishrag 0.04, velvet 0.04, screw 0.03, 0.2ms
# 458: 224x224 paper_towel 0.09, velvet 0.05, dishrag 0.05, tennis_ball 0.04, screw 0.03, 0.2ms
# 459: 224x224 velvet 0.06, tennis_ball 0.05, dishrag 0.05, paper_towel 0.05, vulture 0.03, 0.2ms
# 460: 224x224 paper_towel 0.06, velvet 0.06, tennis_ball 0.05, tick 0.04, dishrag 0.03, 0.2ms
# 461: 224x224 tennis_ball 0.07, velvet 0.04, paper_towel 0.04, dishrag 0.04, vulture 0.03, 0.2ms
# 462: 224x224 dishrag 0.08, paper_towel 0.07, velvet 0.05, tennis_ball 0.04, cardigan 0.04, 0.2ms
# 463: 224x224 tennis_ball 0.08, paper_towel 0.07, velvet 0.06, dishrag 0.05, cardigan 0.03, 0.2ms
# 464: 224x224 velvet 0.05, tennis_ball 0.05, paper_towel 0.04, vulture 0.04, dishrag 0.04, 0.2ms
# 465: 224x224 dishrag 0.14, tennis_ball 0.05, velvet 0.05, paper_towel 0.03, cardigan 0.03, 0.2ms
# 466: 224x224 paper_towel 0.08, velvet 0.06, tick 0.04, tennis_ball 0.04, vulture 0.04, 0.2ms
# 467: 224x224 paper_towel 0.09, tennis_ball 0.06, dishrag 0.05, velvet 0.05, tick 0.03, 0.2ms
# 468: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.06, dishrag 0.05, cardigan 0.04, 0.2ms
# 469: 224x224 dishrag 0.08, paper_towel 0.07, velvet 0.06, tennis_ball 0.04, vulture 0.04, 0.2ms
# 470: 224x224 paper_towel 0.09, dishrag 0.05, velvet 0.04, tennis_ball 0.04, tick 0.03, 0.2ms
# 471: 224x224 paper_towel 0.08, velvet 0.06, tennis_ball 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 472: 224x224 velvet 0.07, paper_towel 0.06, tennis_ball 0.04, tick 0.03, screw 0.03, 0.2ms
# 473: 224x224 dishrag 0.07, velvet 0.06, tennis_ball 0.04, paper_towel 0.03, vulture 0.03, 0.2ms
# 474: 224x224 paper_towel 0.06, velvet 0.05, tennis_ball 0.05, vulture 0.04, dishrag 0.04, 0.2ms
# 475: 224x224 dishrag 0.07, paper_towel 0.06, tennis_ball 0.05, velvet 0.05, screw 0.03, 0.2ms
# 476: 224x224 paper_towel 0.06, velvet 0.05, tennis_ball 0.05, dishrag 0.05, tick 0.04, 0.2ms
# 477: 224x224 paper_towel 0.07, dishrag 0.06, tennis_ball 0.05, velvet 0.04, tick 0.03, 0.2ms
# 478: 224x224 paper_towel 0.07, dishrag 0.07, velvet 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 479: 224x224 paper_towel 0.08, dishrag 0.05, velvet 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 480: 224x224 paper_towel 0.07, velvet 0.05, tennis_ball 0.04, tick 0.03, vulture 0.03, 0.2ms
# 481: 224x224 paper_towel 0.07, velvet 0.07, dishrag 0.06, tennis_ball 0.04, tick 0.04, 0.2ms
# 482: 224x224 dishrag 0.08, velvet 0.07, paper_towel 0.06, tennis_ball 0.03, bubble 0.03, 0.2ms
# 483: 224x224 paper_towel 0.06, tennis_ball 0.05, velvet 0.04, dishrag 0.03, vulture 0.03, 0.2ms
# 484: 224x224 vulture 0.06, velvet 0.05, paper_towel 0.04, tick 0.04, tennis_ball 0.03, 0.2ms
# 485: 224x224 tennis_ball 0.06, paper_towel 0.06, velvet 0.05, dishrag 0.04, cardigan 0.03, 0.2ms
# 486: 224x224 tennis_ball 0.07, velvet 0.06, paper_towel 0.06, dishrag 0.04, screw 0.03, 0.2ms
# 487: 224x224 dishrag 0.09, paper_towel 0.08, velvet 0.05, cardigan 0.04, tennis_ball 0.03, 0.2ms
# 488: 224x224 paper_towel 0.08, velvet 0.05, tennis_ball 0.04, dishrag 0.04, tick 0.03, 0.2ms
# 489: 224x224 paper_towel 0.08, dishrag 0.06, velvet 0.06, tennis_ball 0.05, tick 0.03, 0.2ms
# 490: 224x224 dishrag 0.11, paper_towel 0.08, velvet 0.05, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 491: 224x224 dishrag 0.07, velvet 0.05, tennis_ball 0.05, paper_towel 0.05, wool 0.03, 0.2ms
# 492: 224x224 velvet 0.07, dishrag 0.07, paper_towel 0.06, tennis_ball 0.05, wool 0.03, 0.2ms
# 493: 224x224 paper_towel 0.05, dishrag 0.04, tennis_ball 0.04, velvet 0.03, tick 0.03, 0.2ms
# 494: 224x224 paper_towel 0.09, dishrag 0.07, tennis_ball 0.05, cardigan 0.04, velvet 0.04, 0.2ms
# 495: 224x224 paper_towel 0.09, tennis_ball 0.05, velvet 0.04, vulture 0.04, tick 0.03, 0.2ms
# 496: 224x224 tennis_ball 0.06, velvet 0.04, paper_towel 0.04, vulture 0.03, dishrag 0.03, 0.2ms
# 497: 224x224 paper_towel 0.09, dishrag 0.05, velvet 0.05, tick 0.04, tennis_ball 0.04, 0.2ms
# 498: 224x224 tennis_ball 0.07, paper_towel 0.06, velvet 0.05, dishrag 0.04, bubble 0.03, 0.2ms
# 499: 224x224 velvet 0.07, paper_towel 0.06, dishrag 0.06, tick 0.05, vulture 0.04, 0.2ms
# 500: 224x224 dishrag 0.08, paper_towel 0.07, velvet 0.07, tennis_ball 0.04, tick 0.03, 0.2ms
# 501: 224x224 dishrag 0.08, velvet 0.06, paper_towel 0.06, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 502: 224x224 dishrag 0.08, tennis_ball 0.06, paper_towel 0.06, velvet 0.05, cardigan 0.03, 0.2ms
# ...
# 1834: 224x224 paper_towel 0.05, tennis_ball 0.04, vulture 0.04, velvet 0.03, tick 0.03, 0.2ms
# 1835: 224x224 velvet 0.08, paper_towel 0.07, dishrag 0.07, tick 0.05, tennis_ball 0.04, 0.2ms
# 1836: 224x224 dishrag 0.07, paper_towel 0.06, velvet 0.05, tennis_ball 0.03, tick 0.03, 0.2ms
# 1837: 224x224 dishrag 0.08, paper_towel 0.07, velvet 0.06, tennis_ball 0.05, cardigan 0.04, 0.2ms
# 1838: 224x224 paper_towel 0.09, tennis_ball 0.08, velvet 0.04, dishrag 0.03, cardigan 0.03, 0.2ms
# 1839: 224x224 velvet 0.07, paper_towel 0.06, dishrag 0.06, tennis_ball 0.04, vulture 0.03, 0.2ms
# 1840: 224x224 paper_towel 0.09, dishrag 0.05, tennis_ball 0.05, velvet 0.05, wool 0.03, 0.2ms
# 1841: 224x224 tennis_ball 0.07, dishrag 0.07, paper_towel 0.05, velvet 0.05, cardigan 0.03, 0.2ms
# 1842: 224x224 velvet 0.07, paper_towel 0.06, tennis_ball 0.06, dishrag 0.04, vulture 0.03, 0.2ms
# 1843: 224x224 dishrag 0.08, paper_towel 0.08, velvet 0.05, tennis_ball 0.04, tick 0.04, 0.2ms
# 1844: 224x224 paper_towel 0.08, velvet 0.06, tennis_ball 0.05, tick 0.04, dishrag 0.04, 0.2ms
# 1845: 224x224 dishrag 0.09, paper_towel 0.08, velvet 0.06, tennis_ball 0.04, tick 0.04, 0.2ms
# 1846: 224x224 paper_towel 0.08, dishrag 0.06, velvet 0.04, tennis_ball 0.03, soccer_ball 0.02, 0.2ms
# 1847: 224x224 paper_towel 0.07, dishrag 0.07, velvet 0.06, tennis_ball 0.04, vulture 0.03, 0.2ms
# 1848: 224x224 tennis_ball 0.07, velvet 0.07, dishrag 0.05, paper_towel 0.05, vulture 0.04, 0.2ms
# 1849: 224x224 paper_towel 0.07, dishrag 0.07, velvet 0.05, tennis_ball 0.04, tick 0.03, 0.2ms
# 1850: 224x224 velvet 0.08, paper_towel 0.05, tennis_ball 0.04, tick 0.04, dishrag 0.04, 0.2ms
# 1851: 224x224 velvet 0.07, paper_towel 0.06, dishrag 0.06, tennis_ball 0.05, vulture 0.03, 0.2ms
# 1852: 224x224 paper_towel 0.06, dishrag 0.05, velvet 0.05, tennis_ball 0.04, vulture 0.03, 0.2ms
# 1853: 224x224 dishrag 0.09, paper_towel 0.08, tennis_ball 0.05, cardigan 0.04, velvet 0.04, 0.2ms
# 1854: 224x224 dishrag 0.13, paper_towel 0.06, velvet 0.06, tick 0.03, cardigan 0.03, 0.2ms
# 1855: 224x224 velvet 0.07, paper_towel 0.06, tick 0.05, dishrag 0.05, tennis_ball 0.04, 0.2ms
# 1856: 224x224 dishrag 0.10, velvet 0.07, paper_towel 0.06, tick 0.03, tennis_ball 0.03, 0.2ms
# 1857: 224x224 paper_towel 0.07, velvet 0.06, tennis_ball 0.06, dishrag 0.05, vulture 0.03, 0.2ms
# 1858: 224x224 tennis_ball 0.06, paper_towel 0.05, velvet 0.04, dishrag 0.03, vulture 0.03, 0.2ms
# 1859: 224x224 paper_towel 0.10, velvet 0.06, dishrag 0.05, tick 0.03, tennis_ball 0.03, 0.2ms
# 1860: 224x224 velvet 0.07, paper_towel 0.07, dishrag 0.07, tick 0.03, vulture 0.03, 0.2ms
# 1861: 224x224 dishrag 0.18, paper_towel 0.07, velvet 0.06, cardigan 0.03, wool 0.03, 0.2ms
# 1862: 224x224 dishrag 0.07, velvet 0.06, paper_towel 0.06, tennis_ball 0.04, vulture 0.04, 0.2ms
# 1863: 224x224 velvet 0.07, dishrag 0.05, paper_towel 0.05, tick 0.04, vulture 0.04, 0.2ms
# 1864: 224x224 velvet 0.08, dishrag 0.07, tennis_ball 0.05, paper_towel 0.04, vulture 0.03, 0.2ms
# 1865: 224x224 velvet 0.06, tennis_ball 0.05, paper_towel 0.05, dishrag 0.03, tick 0.03, 0.2ms
# 1866: 224x224 paper_towel 0.09, tick 0.05, tennis_ball 0.04, velvet 0.03, vulture 0.03, 0.2ms
# 1867: 224x224 dishrag 0.07, tennis_ball 0.06, paper_towel 0.06, velvet 0.05, cardigan 0.03, 0.2ms
# 1868: 224x224 paper_towel 0.08, dishrag 0.07, velvet 0.05, vulture 0.03, tennis_ball 0.03, 0.2ms
# 1869: 224x224 vulture 0.06, tennis_ball 0.05, velvet 0.05, paper_towel 0.04, tick 0.04, 0.2ms
# 1870: 224x224 dishrag 0.12, velvet 0.06, tennis_ball 0.05, paper_towel 0.04, cardigan 0.03, 0.2ms
# 1871: 224x224 dishrag 0.09, velvet 0.07, paper_towel 0.06, tennis_ball 0.05, bubble 0.03, 0.2ms
# 1872: 224x224 paper_towel 0.08, velvet 0.05, vulture 0.05, tennis_ball 0.04, tick 0.03, 0.2ms
# 1873: 224x224 dishrag 0.14, paper_towel 0.10, velvet 0.05, cardigan 0.03, bubble 0.03, 0.2ms
# 1874: 224x224 velvet 0.05, paper_towel 0.05, tennis_ball 0.05, dishrag 0.04, screw 0.03, 0.2ms
# 1875: 224x224 paper_towel 0.06, tennis_ball 0.05, velvet 0.04, vulture 0.03, dishrag 0.03, 0.2ms
# 1876: 224x224 dishrag 0.10, velvet 0.08, paper_towel 0.06, tennis_ball 0.06, cardigan 0.03, 0.2ms
# 1877: 224x224 velvet 0.07, paper_towel 0.05, tennis_ball 0.05, vulture 0.04, tick 0.04, 0.2ms
# 1878: 224x224 paper_towel 0.07, tennis_ball 0.06, dishrag 0.04, velvet 0.04, vulture 0.03, 0.2ms
# 1879: 224x224 dishrag 0.08, tennis_ball 0.04, paper_towel 0.04, velvet 0.04, vulture 0.03, 0.2ms
# 1880: 224x224 dishrag 0.09, velvet 0.08, paper_towel 0.05, tennis_ball 0.03, vulture 0.03, 0.2ms
# 1881: 224x224 dishrag 0.07, velvet 0.06, paper_towel 0.06, tick 0.04, tennis_ball 0.03, 0.2ms
# 1882: 224x224 dishrag 0.05, tennis_ball 0.05, velvet 0.05, paper_towel 0.05, tick 0.03, 0.2ms
# 1883: 224x224 paper_towel 0.09, tennis_ball 0.05, velvet 0.04, dishrag 0.04, screw 0.03, 0.2ms
# 1884: 224x224 dishrag 0.07, paper_towel 0.07, velvet 0.05, tennis_ball 0.04, cardigan 0.04, 0.2ms
# 1885: 224x224 dishrag 0.12, paper_towel 0.07, velvet 0.06, tennis_ball 0.03, stole 0.03, 0.2ms
# 1886: 224x224 dishrag 0.11, velvet 0.06, paper_towel 0.06, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 1887: 224x224 paper_towel 0.08, velvet 0.04, vulture 0.04, tennis_ball 0.04, tick 0.04, 0.2ms
# 1888: 224x224 paper_towel 0.07, dishrag 0.07, velvet 0.07, tick 0.04, tennis_ball 0.04, 0.2ms
# 1889: 224x224 paper_towel 0.10, dishrag 0.07, velvet 0.06, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 1890: 224x224 dishrag 0.10, paper_towel 0.06, velvet 0.05, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 1891: 224x224 paper_towel 0.07, tennis_ball 0.05, velvet 0.04, tick 0.04, vulture 0.04, 0.2ms
# 1892: 224x224 paper_towel 0.06, velvet 0.06, tennis_ball 0.05, dishrag 0.04, vulture 0.03, 0.2ms
# 1893: 224x224 dishrag 0.08, paper_towel 0.08, velvet 0.06, tennis_ball 0.04, stole 0.03, 0.2ms
# 1894: 224x224 dishrag 0.06, paper_towel 0.05, velvet 0.05, tennis_ball 0.04, vulture 0.03, 0.2ms
# 1895: 224x224 dishrag 0.06, velvet 0.05, paper_towel 0.04, vulture 0.04, tennis_ball 0.03, 0.2ms
# 1896: 224x224 dishrag 0.10, velvet 0.06, paper_towel 0.05, bubble 0.04, tennis_ball 0.04, 0.2ms
# 1897: 224x224 tennis_ball 0.05, paper_towel 0.05, velvet 0.04, dishrag 0.03, tick 0.03, 0.2ms
# 1898: 224x224 dishrag 0.07, tennis_ball 0.05, paper_towel 0.05, velvet 0.05, screw 0.03, 0.2ms
# 1899: 224x224 dishrag 0.09, velvet 0.08, tennis_ball 0.05, paper_towel 0.04, wool 0.03, 0.2ms
# 1900: 224x224 dishrag 0.08, paper_towel 0.06, tennis_ball 0.05, velvet 0.05, cardigan 0.03, 0.2ms
# 1901: 224x224 paper_towel 0.06, velvet 0.05, vulture 0.05, tennis_ball 0.04, dishrag 0.04, 0.2ms
# 1902: 224x224 tennis_ball 0.07, paper_towel 0.05, velvet 0.04, dishrag 0.04, tick 0.03, 0.2ms
# 1903: 224x224 velvet 0.06, paper_towel 0.05, tennis_ball 0.05, dishrag 0.03, vulture 0.03, 0.2ms
# 1904: 224x224 dishrag 0.08, paper_towel 0.07, velvet 0.06, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 1905: 224x224 dishrag 0.09, paper_towel 0.09, velvet 0.05, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 1906: 224x224 dishrag 0.09, paper_towel 0.08, velvet 0.07, tick 0.03, wool 0.03, 0.2ms
# 1907: 224x224 paper_towel 0.07, velvet 0.05, dishrag 0.05, tennis_ball 0.04, tick 0.03, 0.2ms
# 1908: 224x224 paper_towel 0.10, velvet 0.05, tick 0.04, dishrag 0.04, tennis_ball 0.04, 0.2ms
# 1909: 224x224 paper_towel 0.08, dishrag 0.06, tennis_ball 0.05, velvet 0.04, bubble 0.03, 0.2ms
# 1910: 224x224 tennis_ball 0.06, paper_towel 0.05, velvet 0.05, dishrag 0.04, vulture 0.04, 0.2ms
# 1911: 224x224 paper_towel 0.09, tennis_ball 0.05, velvet 0.04, tick 0.03, dishrag 0.03, 0.2ms
# 1912: 224x224 paper_towel 0.08, velvet 0.06, dishrag 0.06, vulture 0.04, tennis_ball 0.03, 0.2ms
# 1913: 224x224 paper_towel 0.07, velvet 0.05, tennis_ball 0.04, dishrag 0.04, tick 0.03, 0.2ms
# 1914: 224x224 paper_towel 0.07, velvet 0.06, tennis_ball 0.05, tick 0.04, vulture 0.04, 0.2ms
# 1915: 224x224 paper_towel 0.07, velvet 0.04, tennis_ball 0.04, dishrag 0.04, tick 0.03, 0.2ms
# 1916: 224x224 paper_towel 0.06, tennis_ball 0.05, velvet 0.04, tick 0.03, dishrag 0.03, 0.2ms
# 1917: 224x224 tennis_ball 0.06, paper_towel 0.05, velvet 0.05, dishrag 0.04, vulture 0.04, 0.2ms
# 1918: 224x224 tennis_ball 0.07, paper_towel 0.06, velvet 0.06, dishrag 0.04, screw 0.03, 0.2ms
# 1919: 224x224 velvet 0.06, paper_towel 0.06, tennis_ball 0.04, dishrag 0.04, tick 0.03, 0.2ms
# 1920: 224x224 paper_towel 0.06, velvet 0.06, tennis_ball 0.05, tick 0.04, vulture 0.04, 0.2ms
# 1921: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.05, dishrag 0.03, vulture 0.03, 0.2ms
# 1922: 224x224 dishrag 0.06, velvet 0.05, paper_towel 0.05, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 1923: 224x224 paper_towel 0.09, velvet 0.06, dishrag 0.05, tick 0.05, vulture 0.04, 0.2ms
# 1924: 224x224 velvet 0.08, dishrag 0.07, paper_towel 0.06, tick 0.04, tennis_ball 0.03, 0.2ms
# 1925: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.06, vulture 0.04, tennis_ball 0.04, 0.2ms
# 1926: 224x224 paper_towel 0.09, tennis_ball 0.05, velvet 0.04, dishrag 0.04, vulture 0.03, 0.2ms
# 1927: 224x224 paper_towel 0.09, tennis_ball 0.06, dishrag 0.05, velvet 0.05, vulture 0.03, 0.2ms
# 1928: 224x224 paper_towel 0.07, velvet 0.07, tick 0.05, tennis_ball 0.05, dishrag 0.04, 0.2ms
# 1929: 224x224 tennis_ball 0.07, velvet 0.05, dishrag 0.04, paper_towel 0.04, vulture 0.03, 0.2ms
# 1930: 224x224 dishrag 0.07, velvet 0.05, paper_towel 0.05, tennis_ball 0.03, tick 0.03, 0.2ms
# 1931: 224x224 paper_towel 0.07, dishrag 0.05, tennis_ball 0.05, velvet 0.05, tick 0.03, 0.2ms
# 1932: 224x224 dishrag 0.12, tennis_ball 0.05, velvet 0.05, paper_towel 0.04, cardigan 0.03, 0.2ms
# 1933: 224x224 velvet 0.06, tennis_ball 0.06, paper_towel 0.06, dishrag 0.05, cardigan 0.03, 0.2ms
# 1934: 224x224 dishrag 0.08, velvet 0.08, paper_towel 0.06, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 1935: 224x224 paper_towel 0.07, tennis_ball 0.06, dishrag 0.05, velvet 0.05, vulture 0.03, 0.2ms
# 1936: 224x224 paper_towel 0.08, velvet 0.06, tennis_ball 0.04, dishrag 0.04, tick 0.03, 0.2ms
# 1937: 224x224 dishrag 0.08, paper_towel 0.07, tennis_ball 0.05, velvet 0.05, cardigan 0.04, 0.2ms
# 1938: 224x224 tennis_ball 0.07, paper_towel 0.05, velvet 0.04, vulture 0.03, tick 0.03, 0.2ms
# 1939: 224x224 paper_towel 0.06, vulture 0.06, velvet 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 1940: 224x224 paper_towel 0.08, dishrag 0.07, velvet 0.04, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 1941: 224x224 paper_towel 0.07, dishrag 0.06, velvet 0.05, tennis_ball 0.04, tick 0.02, 0.2ms
# 1942: 224x224 paper_towel 0.06, velvet 0.05, tennis_ball 0.04, dishrag 0.04, vulture 0.03, 0.2ms
# 1943: 224x224 paper_towel 0.07, velvet 0.06, dishrag 0.05, tennis_ball 0.05, vulture 0.04, 0.2ms
# 1944: 224x224 dishrag 0.08, velvet 0.05, paper_towel 0.05, tennis_ball 0.05, vulture 0.04, 0.2ms
# 1945: 224x224 dishrag 0.08, paper_towel 0.08, tennis_ball 0.06, velvet 0.05, cardigan 0.03, 0.2ms
# 1946: 224x224 velvet 0.07, paper_towel 0.05, tennis_ball 0.05, dishrag 0.04, tick 0.04, 0.2ms
# 1947: 224x224 dishrag 0.07, paper_towel 0.05, velvet 0.05, bubble 0.04, tennis_ball 0.03, 0.2ms
# 1948: 224x224 velvet 0.08, paper_towel 0.05, dishrag 0.05, tennis_ball 0.04, tick 0.04, 0.2ms
# 1949: 224x224 dishrag 0.17, paper_towel 0.06, velvet 0.05, cardigan 0.04, tennis_ball 0.04, 0.2ms
# 1950: 224x224 tennis_ball 0.06, dishrag 0.05, paper_towel 0.04, velvet 0.04, vulture 0.04, 0.2ms
# 1951: 224x224 tennis_ball 0.07, paper_towel 0.05, velvet 0.04, dishrag 0.04, vulture 0.03, 0.2ms
# 1952: 224x224 velvet 0.06, paper_towel 0.06, tennis_ball 0.05, dishrag 0.05, tick 0.03, 0.2ms
# 1953: 224x224 paper_towel 0.09, dishrag 0.07, velvet 0.05, bubble 0.03, cardigan 0.03, 0.2ms
# 1954: 224x224 paper_towel 0.05, tennis_ball 0.05, dishrag 0.04, velvet 0.04, vulture 0.03, 0.2ms
# 1955: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.04, dishrag 0.03, screw 0.02, 0.2ms
# 1956: 224x224 paper_towel 0.07, dishrag 0.06, tennis_ball 0.04, velvet 0.04, tick 0.03, 0.2ms
# 1957: 224x224 dishrag 0.09, paper_towel 0.07, velvet 0.04, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 1958: 224x224 paper_towel 0.06, tennis_ball 0.05, velvet 0.04, tick 0.03, dishrag 0.03, 0.2ms
# 1959: 224x224 dishrag 0.07, paper_towel 0.07, tennis_ball 0.05, velvet 0.04, bubble 0.03, 0.2ms
# 1960: 224x224 dishrag 0.09, velvet 0.07, paper_towel 0.05, tennis_ball 0.04, cardigan 0.03, 0.2ms
# 1961: 224x224 paper_towel 0.07, tennis_ball 0.05, velvet 0.05, dishrag 0.04, vulture 0.04, 0.2ms
# 1962: 224x224 dishrag 0.09, paper_towel 0.08, velvet 0.06, tick 0.04, tennis_ball 0.04, 0.2ms
# 1963: 224x224 paper_towel 0.08, tennis_ball 0.07, velvet 0.05, dishrag 0.04, tick 0.04, 0.2ms
# 1964: 224x224 paper_towel 0.06, tennis_ball 0.05, velvet 0.04, vulture 0.03, dishrag 0.03, 0.2ms
# 1965: 224x224 dishrag 0.06, velvet 0.06, paper_towel 0.05, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 1966: 224x224 paper_towel 0.10, dishrag 0.07, velvet 0.05, tennis_ball 0.04, tick 0.03, 0.2ms
# 1967: 224x224 paper_towel 0.09, velvet 0.07, dishrag 0.06, tennis_ball 0.05, tick 0.03, 0.2ms
# 1968: 224x224 tennis_ball 0.06, paper_towel 0.05, velvet 0.04, vulture 0.03, tick 0.02, 0.2ms
# 1969: 224x224 paper_towel 0.06, velvet 0.06, tennis_ball 0.06, dishrag 0.04, vulture 0.03, 0.2ms
# 1970: 224x224 paper_towel 0.06, dishrag 0.06, velvet 0.04, tennis_ball 0.04, bubble 0.03, 0.2ms
# 1971: 224x224 tennis_ball 0.07, velvet 0.07, paper_towel 0.07, dishrag 0.06, cardigan 0.03, 0.2ms
# 1972: 224x224 velvet 0.07, tennis_ball 0.06, paper_towel 0.06, dishrag 0.05, tick 0.03, 0.2ms
# 1973: 224x224 paper_towel 0.07, velvet 0.06, dishrag 0.05, tennis_ball 0.04, vulture 0.04, 0.2ms
# 1974: 224x224 dishrag 0.07, paper_towel 0.06, velvet 0.06, tennis_ball 0.04, bubble 0.03, 0.2ms
# 1975: 224x224 dishrag 0.09, paper_towel 0.06, velvet 0.06, tennis_ball 0.05, cardigan 0.03, 0.2ms
# 1976: 224x224 dishrag 0.09, paper_towel 0.06, tennis_ball 0.06, velvet 0.05, cardigan 0.04, 0.2ms
# 1977: 224x224 tennis_ball 0.07, paper_towel 0.05, velvet 0.04, tick 0.03, vulture 0.03, 0.2ms
# 1978: 224x224 dishrag 0.09, velvet 0.06, paper_towel 0.06, tennis_ball 0.04, vulture 0.03, 0.2ms
# 1979: 224x224 paper_towel 0.09, velvet 0.06, dishrag 0.05, tick 0.05, tennis_ball 0.04, 0.2ms
# 1980: 224x224 dishrag 0.06, velvet 0.06, tennis_ball 0.05, paper_towel 0.05, vulture 0.03, 0.2ms
# 1981: 224x224 paper_towel 0.08, dishrag 0.07, velvet 0.06, tick 0.04, tennis_ball 0.04, 0.2ms
# 1982: 224x224 dishrag 0.14, velvet 0.08, paper_towel 0.06, wool 0.03, tennis_ball 0.03, 0.2ms
# 1983: 224x224 paper_towel 0.09, dishrag 0.08, velvet 0.06, vulture 0.04, tick 0.04, 0.2ms
# 1984: 224x224 dishrag 0.07, velvet 0.06, paper_towel 0.05, tennis_ball 0.05, cardigan 0.04, 0.2ms
# 1985: 224x224 velvet 0.06, paper_towel 0.06, dishrag 0.05, tennis_ball 0.05, tick 0.03, 0.2ms
# 1986: 224x224 dishrag 0.07, velvet 0.05, paper_towel 0.05, tick 0.04, tennis_ball 0.04, 0.2ms
# 1987: 224x224 paper_towel 0.07, tennis_ball 0.05, vulture 0.03, tick 0.03, velvet 0.03, 0.2ms
# 1988: 224x224 paper_towel 0.06, velvet 0.06, dishrag 0.06, tennis_ball 0.06, cardigan 0.03, 0.2ms
# 1989: 224x224 velvet 0.08, dishrag 0.07, paper_towel 0.05, tennis_ball 0.03, vulture 0.03, 0.2ms
# 1990: 224x224 dishrag 0.12, paper_towel 0.08, velvet 0.05, tennis_ball 0.04, cardigan 0.04, 0.2ms
# 1991: 224x224 velvet 0.06, tennis_ball 0.06, paper_towel 0.06, dishrag 0.05, tick 0.02, 0.2ms
# 1992: 224x224 paper_towel 0.08, velvet 0.05, dishrag 0.05, tennis_ball 0.05, vulture 0.03, 0.2ms
# 1993: 224x224 velvet 0.05, paper_towel 0.05, tennis_ball 0.04, vulture 0.04, tick 0.04, 0.2ms
# 1994: 224x224 paper_towel 0.08, dishrag 0.07, velvet 0.05, tennis_ball 0.03, cardigan 0.03, 0.2ms
# 1995: 224x224 paper_towel 0.07, tennis_ball 0.06, velvet 0.05, dishrag 0.04, bubble 0.03, 0.2ms
# 1996: 224x224 paper_towel 0.06, velvet 0.05, tennis_ball 0.05, dishrag 0.04, tick 0.03, 0.2ms
# 1997: 224x224 paper_towel 0.09, velvet 0.06, tennis_ball 0.04, dishrag 0.04, tick 0.04, 0.2ms
# 1998: 224x224 dishrag 0.13, paper_towel 0.08, velvet 0.05, tennis_ball 0.03, cardigan 0.03, 0.2ms
# 1999: 224x224 paper_towel 0.06, velvet 0.06, tennis_ball 0.04, dishrag 0.04, tick 0.04, 0.2ms
# Speed: 0.0ms preprocess, 0.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
# Display average speed
print(f"Average inference time per image: {sum(times) / 2000:.4f} seconds")
print(f"Average speed: {len(images) / sum(times):.2f} images/second")
# Out:
# Average inference time per image: 0.0006 seconds
# Average speed: 1592.55 images/second

# %% [markdown]
# ## Add Scale Divide to ONNX

# %%
import onnx
from onnx import helper, numpy_helper, TensorProto
def insert_divide_by_255_layer(model_path, output_path):
  # Load the ONNX model
  model = onnx.load(model_path)
  graph = model.graph
  # Identify the input node
  input_name = graph.input[0].name
  input_shape = graph.input[0].type.tensor_type.shape.dim
  input_shape = [dim.dim_value for dim in input_shape]
  # Create a constant node for the value 255
  const_value = numpy_helper.from_array(np.array([255.0],dtype=np.float32), name="const_255")
  const_node = helper.make_node(
              'Constant',
              inputs=[],
              outputs=['const_255'],
              value=const_value
              )
  # Create a divide node
  div_node = helper.make_node(
              'Div',
              inputs=[input_name, 'const_255'],
              outputs=['normalized_input']
              )
  # Find the node that consumes the input
  for node in graph.node:
    for i, input in enumerate(node.input):
      if input == input_name:
        node.input[i] = 'normalized_input'

  # Add the new nodes to the graph
  graph.node.insert(0, const_node)
  graph.node.insert(1, div_node)
  # Save the modified model
  onnx.save(model, output_path)

# %%
model_path = 'yolov8n-cls.onnx'
output_path = 'model_div255.onnx'
insert_divide_by_255_layer(model_path, output_path)

# %% [markdown]
# OpenVINO command to compile
#
# `mo --input_model model_div255.onnx  --output_dir ./yolov8  --reverse_input_channels`

# %% [markdown]
# ```
# dla_compiler --march $COREDLA_ROOT/example_architectures/AGX7_Performance.arch --network-file ./model_div255.xml --foutput-format=open_vino_hetero --o ./yolov8_bench.bin --batch-size=1 --fanalyze-performance
# ```

# %% [markdown]
# Divider with the OpenVINO `mo` tools

# %% [markdown]
# `mo --input_model yolov8n-cls.onnx -s 255 --output_dir ./yolov8_s --reverse_input_channels`

# %% [markdown]
# ```
# dla_compiler --march $COREDLA_ROOT/example_architectures/AGX7_Performance.arch --network-file ./yolov8n-cls.xml --foutput-format=open_vino_hetero --o ./yolov8_bench.bin --batch-size=1 --fanalyze-performance
# ```
